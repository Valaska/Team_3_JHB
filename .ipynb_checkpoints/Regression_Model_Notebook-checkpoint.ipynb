# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 60)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['font.size'] = 20
from IPython.core.pylabtools import figsize
from sklearn.model_selection import train_test_split

# Imputing missing values and scaling values
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

# Machine Learning Models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# Performance of Models
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# We were given to sets of data so we merge them so we can make use of all our variables

# %%
train = pd.read_csv('https://raw.githubusercontent.com/Valaska/Team_3_JHB/master/regression_dataset/Train.csv')
riders = pd.read_csv('https://raw.githubusercontent.com/Valaska/Team_3_JHB/master/regression_dataset/Riders.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Valaska/Team_3_JHB/master/regression_dataset/Test.csv')
train_data = pd.merge(train, riders, how='inner', on='Rider Id')
test_data = pd.merge(test, riders, how = 'inner', on= 'Rider Id')

# %%
train_copy = train_data.copy()
test_copy = test_data.copy()

# %%
train_data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_27440  User_Id_2642         Bike              3
# 2  Order_No_14170  User_Id_3339         Bike              3
# 3  Order_No_21727  User_Id_3523         Bike              3
# 4   Order_No_8301    User_Id_87         Bike              2
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        18
# 2             Business                        31
# 3             Personal                         2
# 4             Personal                        22
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5       3:41:17 PM                           18
# 2                             5      12:51:41 PM                           31
# 3                             2       7:12:10 AM                            2
# 4                             2      10:40:58 AM                           22
#
#    Confirmation - Weekday (Mo = 1) Confirmation - Time  \
# 0                                5          9:40:10 AM
# 1                                5          3:41:30 PM
# 2                                5          1:12:49 PM
# 3                                2          7:12:29 AM
# 4                                2         10:42:24 AM
#
#    Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# 0                                 9                                     5
# 1                                18                                     5
# 2                                31                                     5
# 3                                 2                                     2
# 4                                22                                     2
#
#   Arrival at Pickup - Time  Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# 0              10:04:47 AM                      9                          5
# 1               4:07:16 PM                     18                          5
# 2               1:20:02 PM                     31                          5
# 3               7:35:24 AM                      2                          2
# 4              10:56:00 AM                     22                          2
#
#   Pickup - Time  Arrival at Destination - Day of Month  \
# 0   10:27:30 AM                                      9
# 1    4:13:37 PM                                     18
# 2    1:33:08 PM                                     31
# 3    7:38:46 AM                                      2
# 4   10:59:40 AM                                     22
#
#    Arrival at Destination - Weekday (Mo = 1) Arrival at Destination - Time  \
# 0                                          5                   10:39:55 AM
# 1                                          5                    5:01:43 PM
# 2                                          5                    2:16:43 PM
# 3                                          2                    8:28:32 AM
# 4                                          2                   11:26:22 AM
#
#    Distance (KM)  Temperature  Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                           NaN   -1.317755
# 1             20         24.5                           NaN   -1.326774
# 2              6         24.7                           NaN   -1.255189
# 3             18         15.2                           NaN   -1.290315
# 4              7         19.2                           NaN   -1.273524
#
#    Pickup Long  Destination Lat  Destination Long      Rider Id  \
# 0    36.830370        -1.300406         36.829741  Rider_Id_432
# 1    36.787807        -1.356237         36.904295  Rider_Id_432
# 2    36.782203        -1.273412         36.818206  Rider_Id_432
# 3    36.757377        -1.223520         36.802061  Rider_Id_432
# 4    36.799220        -1.300431         36.752427  Rider_Id_432
#
#    Time from Pickup to Arrival  No_Of_Orders   Age  Average_Rating  \
# 0                          745          1637  1309            13.8
# 1                         2886          1637  1309            13.8
# 2                         2615          1637  1309            13.8
# 3                         2986          1637  1309            13.8
# 4                         1602          1637  1309            13.8
#
#    No_of_Ratings
# 0            549
# 1            549
# 2            549
# 3            549
# 4            549

# %% [markdown]
# Initials thought on our data?

# %% [markdown]
# **Data types**

# %%
train_data.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 33 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Placement - Time                             21201 non-null object
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Confirmation - Time                          21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Arrival at Pickup - Time                     21201 non-null object
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Pickup - Time                                21201 non-null object
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Arrival at Destination - Time                21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  16835 non-null float64
# Precipitation in millimeters                 552 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# No_Of_Orders                                 21201 non-null int64
# Age                                          21201 non-null int64
# Average_Rating                               21201 non-null float64
# No_of_Ratings                                21201 non-null int64
# dtypes: float64(7), int64(16), object(10)
# memory usage: 5.5+ MB

# %% [markdown]
# Missing values in our dataset

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(train_data)
# Out:
# Your selected dataframe has 33 columns.
# There are 2 columns that have missing values.
#                               Missing Values  % of Total Values
# Precipitation in millimeters           20649               97.4
# Temperature                             4366               20.6

# %% [markdown]
# As we can see from the above table there are two columns with missing values. Temperature has 20.6 % missing values which is not
# enough reason to drop the column so we instead replace the missing values with the mean value of the temperatures.
# For the Percipitation in millimeters it is clear that majority of the values are missing although due to the lack of information
# we are making an assumption that if there was a missing value that no rain occured that day and would like to test the influence
# this variable with have on our target value.

# %% [markdown]
# Replace NaN values in Precipitation in millimeters column with O

# %%
train_data['Precipitation in millimeters'].fillna(value=0, inplace=True)
test_data['Precipitation in millimeters'].fillna(value=0, inplace=True)

# %% [markdown]
# Replace missing values in the Temperature column with the average temperature

# %%
from sklearn.impute import SimpleImputer

from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')


imputer.fit(train_data[["Temperature"]])
train_data["Temperature"]=imputer.transform(train_data[["Temperature"]]).ravel()
test_data["Temperature"]=imputer.transform(test_data[["Temperature"]]).ravel()

# %% [markdown]
# Change our time data to 24 hours

# %%
 def change_time(df, col):
    
    df['timestampx'] = pd.to_datetime(df[col], format='%I:%M:%S %p')
        
    a = []
    for i in df['timestampx']:
        a.append(i.time().strftime('%H:%M:%S'))
    df[col] = pd.DataFrame(a)
    df.drop('timestampx', axis = 1, inplace = True)
    
    return df

# %%
change_time(train_data, 'Placement - Time')
change_time(train_data, 'Confirmation - Time')
change_time(train_data, 'Arrival at Destination - Time')
change_time(train_data, 'Pickup - Time')
change_time(train_data, 'Arrival at Pickup - Time')
change_time(test_data, 'Arrival at Pickup - Time')
change_time(test_data, 'Placement - Time')
change_time(test_data, 'Confirmation - Time')
change_time(test_data, 'Pickup - Time')
# Out:
#             Order No       User Id Vehicle Type  Platform Type  \
# 0     Order_No_19248  User_Id_3355         Bike              3
# 1      Order_No_2699   User_Id_592         Bike              1
# 2     Order_No_21486   User_Id_478         Bike              3
# 3     Order_No_19336  User_Id_2801         Bike              3
# 4     Order_No_20374  User_Id_3465         Bike              3
# 5      Order_No_9830  User_Id_1926         Bike              3
# 6     Order_No_17505   User_Id_978         Bike              1
# 7     Order_No_23802  User_Id_2445         Bike              2
# 8     Order_No_12736  User_Id_3647         Bike              3
# 9      Order_No_6400   User_Id_299         Bike              3
# 10    Order_No_25920  User_Id_1402         Bike              3
# 11    Order_No_24873  User_Id_2330         Bike              3
# 12     Order_No_4511  User_Id_2154         Bike              3
# 13    Order_No_13686  User_Id_2187         Bike              3
# 14    Order_No_19317   User_Id_627         Bike              3
# 15     Order_No_2680  User_Id_3686         Bike              3
# 16     Order_No_7097  User_Id_2801         Bike              3
# 17    Order_No_22701  User_Id_3086         Bike              3
# 18     Order_No_4881  User_Id_2190         Bike              3
# 19     Order_No_6340  User_Id_3283         Bike              3
# 20    Order_No_27915   User_Id_467         Bike              3
# 21      Order_No_768  User_Id_2154         Bike              3
# 22    Order_No_28256  User_Id_1246         Bike              3
# 23    Order_No_16940  User_Id_3291         Bike              3
# 24     Order_No_4860  User_Id_1329         Bike              3
# 25    Order_No_19055  User_Id_1277         Bike              3
# 26    Order_No_21272  User_Id_1329         Bike              3
# 27     Order_No_2131   User_Id_393         Bike              3
# 28    Order_No_26647  User_Id_2200         Bike              3
# 29    Order_No_15717  User_Id_2423         Bike              3
# ...              ...           ...          ...            ...
# 7038  Order_No_15305  User_Id_3247         Bike              3
# 7039    Order_No_881    User_Id_60         Bike              3
# 7040  Order_No_14836  User_Id_3621         Bike              3
# 7041  Order_No_15718  User_Id_3613         Bike              3
# 7042  Order_No_17254   User_Id_186         Bike              3
# 7043  Order_No_22379  User_Id_1291         Bike              3
# 7044  Order_No_11001  User_Id_1500         Bike              3
# 7045  Order_No_19817   User_Id_970         Bike              3
# 7046  Order_No_16673  User_Id_2924         Bike              3
# 7047  Order_No_27727  User_Id_1522         Bike              3
# 7048    Order_No_728  User_Id_3032         Bike              3
# 7049  Order_No_11373  User_Id_1075         Bike              3
# 7050   Order_No_8931   User_Id_540         Bike              3
# 7051   Order_No_3733  User_Id_3674         Bike              3
# 7052  Order_No_20900  User_Id_3080         Bike              3
# 7053  Order_No_16512  User_Id_1199         Bike              1
# 7054  Order_No_11372   User_Id_837         Bike              3
# 7055   Order_No_5173  User_Id_2150         Bike              3
# 7056   Order_No_3367   User_Id_432         Bike              3
# 7057  Order_No_13945   User_Id_248         Bike              3
# 7058  Order_No_26588  User_Id_2691         Bike              3
# 7059  Order_No_25495  User_Id_3326         Bike              3
# 7060   Order_No_6959   User_Id_136         Bike              3
# 7061   Order_No_1036  User_Id_3647         Bike              3
# 7062  Order_No_12348  User_Id_3186         Bike              3
# 7063   Order_No_5207   User_Id_635         Bike              3
# 7064  Order_No_11108  User_Id_2154         Bike              3
# 7065  Order_No_15696  User_Id_1899         Bike              3
# 7066  Order_No_14332  User_Id_1245         Bike              3
# 7067  Order_No_21633   User_Id_103         Bike              3
#
#      Personal or Business  Placement - Day of Month  \
# 0                Business                        27
# 1                Personal                        26
# 2                Business                        29
# 3                Business                         2
# 4                Business                        14
# 5                Business                        30
# 6                Personal                        11
# 7                Personal                        17
# 8                Business                        17
# 9                Business                         3
# 10               Business                        18
# 11               Business                        21
# 12               Business                        13
# 13               Business                        13
# 14               Business                        10
# 15               Business                        10
# 16               Business                        12
# 17               Business                        31
# 18               Business                        12
# 19               Business                        25
# 20               Business                        23
# 21               Business                        27
# 22               Business                        14
# 23               Business                         9
# 24               Business                         3
# 25               Business                        14
# 26               Business                         6
# 27               Business                         7
# 28               Business                         5
# 29               Business                         9
# ...                   ...                       ...
# 7038             Business                        27
# 7039             Business                        19
# 7040             Business                        28
# 7041             Business                         1
# 7042             Business                         4
# 7043             Personal                         7
# 7044             Business                        31
# 7045             Business                         8
# 7046             Personal                        25
# 7047             Business                        13
# 7048             Business                         6
# 7049             Business                        21
# 7050             Business                         5
# 7051             Business                        12
# 7052             Business                        14
# 7053             Personal                         1
# 7054             Personal                        24
# 7055             Business                        24
# 7056             Business                         1
# 7057             Business                         5
# 7058             Business                         5
# 7059             Business                         9
# 7060             Business                        14
# 7061             Business                         4
# 7062             Business                         5
# 7063             Business                         8
# 7064             Business                         9
# 7065             Business                        31
# 7066             Business                        11
# 7067             Business                        27
#
#       Placement - Weekday (Mo = 1) Placement - Time  \
# 0                                3         16:44:10
# 1                                2         14:43:21
# 2                                5         11:55:05
# 3                                1         09:23:21
# 4                                4         12:55:59
# 5                                4         12:39:17
# 6                                1         15:26:33
# 7                                4         12:58:47
# 8                                5         12:57:35
# 9                                1         10:38:31
# 10                               6         11:51:24
# 11                               2         16:16:06
# 12                               4         15:09:05
# 13                               1         14:47:24
# 14                               1         15:25:33
# 15                               1         10:06:03
# 16                               3         10:03:19
# 17                               5         17:44:11
# 18                               3         13:41:04
# 19                               1         11:51:01
# 20                               4         12:46:17
# 21                               4         11:08:14
# 22                               1         14:37:31
# 23                               6         08:40:54
# 24                               4         11:18:27
# 25                               5         11:22:03
# 26                               3         13:53:47
# 27                               4         11:36:25
# 28                               6         11:38:27
# 29                               3         14:01:56
# ...                            ...              ...
# 7038                             2         14:23:43
# 7039                             1         14:12:40
# 7040                             5         14:05:13
# 7041                             5         10:22:58
# 7042                             2         09:00:32
# 7043                             4         11:16:46
# 7044                             2         14:24:30
# 7045                             3         10:42:36
# 7046                             5         13:06:03
# 7047                             4         15:51:56
# 7048                             4         14:45:20
# 7049                             1         10:10:15
# 7050                             3         14:24:10
# 7051                             5         13:01:43
# 7052                             4         11:14:24
# 7053                             1         11:49:57
# 7054                             2         17:43:35
# 7055                             3         11:05:12
# 7056                             1         11:24:17
# 7057                             3         17:00:56
# 7058                             4         09:57:29
# 7059                             3         10:03:01
# 7060                             4         10:52:04
# 7061                             5         17:27:20
# 7062                             2         15:45:11
# 7063                             5         12:56:22
# 7064                             3         15:08:38
# 7065                             5         13:25:34
# 7066                             1         08:55:12
# 7067                             6         12:50:14
#
#       Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                              27                                3
# 1                              26                                2
# 2                              29                                5
# 3                               2                                1
# 4                              14                                4
# 5                              30                                4
# 6                              11                                1
# 7                              17                                4
# 8                              17                                5
# 9                               3                                1
# 10                             18                                6
# 11                             21                                2
# 12                             13                                4
# 13                             13                                1
# 14                             10                                1
# 15                             10                                1
# 16                             12                                3
# 17                             31                                5
# 18                             12                                3
# 19                             25                                1
# 20                             23                                4
# 21                             27                                4
# 22                             14                                1
# 23                              9                                6
# 24                              3                                4
# 25                             14                                5
# 26                              6                                3
# 27                              7                                4
# 28                              5                                6
# 29                              9                                3
# ...                           ...                              ...
# 7038                           27                                2
# 7039                           19                                1
# 7040                           28                                5
# 7041                            1                                5
# 7042                            4                                2
# 7043                            7                                4
# 7044                           31                                2
# 7045                            8                                3
# 7046                           25                                5
# 7047                           13                                4
# 7048                            6                                4
# 7049                           21                                1
# 7050                            5                                3
# 7051                           12                                5
# 7052                           14                                4
# 7053                            1                                1
# 7054                           24                                2
# 7055                           24                                3
# 7056                            1                                1
# 7057                            5                                3
# 7058                            5                                4
# 7059                            9                                3
# 7060                           14                                4
# 7061                            4                                5
# 7062                            5                                2
# 7063                            8                                5
# 7064                            9                                3
# 7065                           31                                5
# 7066                           11                                1
# 7067                           27                                6
#
#      Confirmation - Time  Arrival at Pickup - Day of Month  \
# 0               16:44:29                                27
# 1               14:47:16                                26
# 2               11:58:12                                29
# 3               09:23:44                                 2
# 4               13:22:44                                14
# 5               12:40:17                                30
# 6               15:27:47                                11
# 7               12:58:55                                17
# 8               12:59:17                                17
# 9               10:38:46                                 3
# 10              11:53:11                                18
# 11              16:16:29                                21
# 12              15:26:08                                13
# 13              15:11:28                                13
# 14              15:31:06                                10
# 15              10:06:39                                10
# 16              10:03:33                                12
# 17              17:48:48                                31
# 18              13:44:54                                12
# 19              11:51:26                                25
# 20              12:46:41                                23
# 21              11:25:05                                27
# 22              14:45:07                                14
# 23              08:41:15                                 9
# 24              11:18:57                                 3
# 25              11:22:08                                14
# 26              13:54:58                                 6
# 27              11:36:43                                 7
# 28              11:38:52                                 5
# 29              14:12:42                                 9
# ...                  ...                               ...
# 7038            14:25:04                                27
# 7039            14:13:02                                19
# 7040            14:05:38                                28
# 7041            10:26:26                                 1
# 7042            09:11:09                                 4
# 7043            11:17:33                                 7
# 7044            14:24:34                                31
# 7045            10:43:11                                 8
# 7046            14:21:04                                25
# 7047            15:55:23                                13
# 7048            15:09:16                                 6
# 7049            10:10:23                                21
# 7050            14:24:23                                 5
# 7051            13:02:00                                12
# 7052            11:14:35                                14
# 7053            11:51:13                                 1
# 7054            17:44:45                                24
# 7055            11:06:16                                24
# 7056            11:25:01                                 1
# 7057            17:01:10                                 5
# 7058            09:58:24                                 5
# 7059            10:04:35                                 9
# 7060            10:53:08                                14
# 7061            17:28:09                                 4
# 7062            15:49:28                                 5
# 7063            13:43:10                                 8
# 7064            15:17:47                                 9
# 7065            13:32:50                                31
# 7066            08:55:46                                11
# 7067            12:50:58                                27
#
#       Arrival at Pickup - Weekday (Mo = 1) Arrival at Pickup - Time  \
# 0                                        3                 16:53:04
# 1                                        2                 15:09:26
# 2                                        5                 12:25:49
# 3                                        1                 09:44:50
# 4                                        4                 13:49:38
# 5                                        4                 13:04:53
# 6                                        1                 15:38:18
# 7                                        4                 13:31:18
# 8                                        5                 13:20:27
# 9                                        1                 10:43:18
# 10                                       6                 12:19:09
# 11                                       2                 16:35:38
# 12                                       4                 15:49:24
# 13                                       1                 15:45:50
# 14                                       1                 16:09:00
# 15                                       1                 10:11:03
# 16                                       3                 10:19:11
# 17                                       5                 18:10:18
# 18                                       3                 14:00:19
# 19                                       1                 11:54:40
# 20                                       4                 13:04:31
# 21                                       4                 11:33:20
# 22                                       1                 14:46:22
# 23                                       6                 09:33:44
# 24                                       4                 11:35:33
# 25                                       5                 11:22:25
# 26                                       3                 14:01:02
# 27                                       4                 11:36:48
# 28                                       6                 11:47:45
# 29                                       3                 14:28:28
# ...                                    ...                      ...
# 7038                                     2                 14:32:19
# 7039                                     1                 14:23:50
# 7040                                     5                 14:29:14
# 7041                                     5                 10:35:09
# 7042                                     2                 09:48:42
# 7043                                     4                 11:29:57
# 7044                                     2                 14:25:01
# 7045                                     3                 10:50:29
# 7046                                     5                 14:56:17
# 7047                                     4                 16:06:51
# 7048                                     4                 15:19:02
# 7049                                     1                 10:12:40
# 7050                                     3                 14:24:48
# 7051                                     5                 13:15:15
# 7052                                     4                 11:15:05
# 7053                                     1                 11:53:39
# 7054                                     2                 17:45:05
# 7055                                     3                 11:14:11
# 7056                                     1                 11:37:45
# 7057                                     3                 17:10:40
# 7058                                     4                 10:07:59
# 7059                                     3                 10:12:27
# 7060                                     4                 11:05:39
# 7061                                     5                 17:45:49
# 7062                                     2                 16:13:21
# 7063                                     5                 14:01:04
# 7064                                     3                 15:23:45
# 7065                                     5                 13:36:35
# 7066                                     1                 09:03:12
# 7067                                     6                 12:55:48
#
#       Pickup - Day of Month  Pickup - Weekday (Mo = 1) Pickup - Time  \
# 0                        27                          3      17:06:47
# 1                        26                          2      15:17:48
# 2                        29                          5      12:28:54
# 3                         2                          1      10:05:31
# 4                        14                          4      13:51:49
# 5                        30                          4      13:19:38
# 6                        11                          1      15:47:57
# 7                        17                          4      13:36:40
# 8                        17                          5      13:25:37
# 9                         3                          1      10:54:09
# 10                       18                          6      12:34:40
# 11                       21                          2      16:40:45
# 12                       13                          4      15:52:28
# 13                       13                          1      15:50:17
# 14                       10                          1      16:11:36
# 15                       10                          1      10:16:08
# 16                       12                          3      10:21:43
# 17                       31                          5      18:15:58
# 18                       12                          3      14:06:38
# 19                       25                          1      11:59:45
# 20                       23                          4      13:08:36
# 21                       27                          4      11:57:54
# 22                       14                          1      15:05:01
# 23                        9                          6      09:48:58
# 24                        3                          4      11:38:55
# 25                       14                          5      11:36:40
# 26                        6                          3      14:07:17
# 27                        7                          4      12:06:19
# 28                        5                          6      11:52:40
# 29                        9                          3      14:48:25
# ...                     ...                        ...           ...
# 7038                     27                          2      15:05:10
# 7039                     19                          1      14:34:01
# 7040                     28                          5      14:34:33
# 7041                      1                          5      10:36:13
# 7042                      4                          2      09:50:37
# 7043                      7                          4      11:35:54
# 7044                     31                          2      14:44:21
# 7045                      8                          3      11:01:26
# 7046                     25                          5      14:59:34
# 7047                     13                          4      16:10:48
# 7048                      6                          4      15:32:56
# 7049                     21                          1      10:27:47
# 7050                      5                          3      14:29:44
# 7051                     12                          5      13:22:20
# 7052                     14                          4      11:49:23
# 7053                      1                          1      12:00:13
# 7054                     24                          2      18:15:11
# 7055                     24                          3      11:20:38
# 7056                      1                          1      11:46:05
# 7057                      5                          3      17:13:35
# 7058                      5                          4      10:13:58
# 7059                      9                          3      10:28:30
# 7060                     14                          4      11:12:04
# 7061                      4                          5      18:11:29
# 7062                      5                          2      16:37:25
# 7063                      8                          5      14:46:12
# 7064                      9                          3      15:38:22
# 7065                     31                          5      13:42:45
# 7066                     11                          1      09:38:19
# 7067                     27                          6      13:12:28
#
#       Distance (KM)  Temperature  Precipitation in millimeters  Pickup Lat  \
# 0                 8    23.258889                           0.0   -1.333275
# 1                19    23.258889                           0.0   -1.312745
# 2                 9    19.700000                           0.0   -1.255189
# 3                15    16.400000                           0.0   -1.310451
# 4                15    21.300000                           0.0   -1.333275
# 5                 7    20.300000                           0.0   -1.333275
# 6                 7    23.000000                           0.0   -1.308407
# 7                16    24.100000                           0.0   -1.332840
# 8                 5    23.258889                           0.0   -1.272639
# 9                15    21.500000                           0.0   -1.262864
# 10                1    21.100000                           0.0   -1.290894
# 11               11    23.900000                           0.0   -1.344358
# 12                5    23.200000                           0.0   -1.276574
# 13               15    23.258889                           0.0   -1.356237
# 14               10    18.100000                           0.0   -1.255189
# 15               10    16.300000                           0.0   -1.255189
# 16                5    23.258889                           0.0   -1.267427
# 17                5    23.800000                           0.0   -1.288991
# 18                9    20.900000                           0.0   -1.301953
# 19                7    27.100000                           0.0   -1.303596
# 20                4    23.400000                           0.0   -1.282070
# 21                5    22.800000                           0.0   -1.290894
# 22                9    26.000000                           0.0   -1.257147
# 23               12    21.000000                           0.0   -1.331619
# 24                5    23.600000                           0.0   -1.273056
# 25                6    21.400000                           0.0   -1.307787
# 26                6    23.258889                           0.0   -1.273056
# 27                8    24.100000                           0.0   -1.316711
# 28                2    22.300000                           0.0   -1.279395
# 29               12    25.500000                           0.0   -1.326938
# ...             ...          ...                           ...         ...
# 7038             23    25.500000                           0.0   -1.343439
# 7039             14    25.000000                           0.0   -1.262847
# 7040              5    25.600000                           0.0   -1.283658
# 7041              7    26.600000                           0.0   -1.264703
# 7042             18    16.400000                          99.1   -1.370038
# 7043              8    27.800000                           0.0   -1.296310
# 7044             12    22.000000                           0.0   -1.257422
# 7045              2    23.258889                           0.0   -1.256746
# 7046              8    23.400000                           0.0   -1.284654
# 7047             14    23.200000                           0.0   -1.207546
# 7048             20    23.258889                           0.0   -1.257147
# 7049              1    22.300000                           0.0   -1.264960
# 7050              4    24.000000                           0.0   -1.255189
# 7051              3    26.500000                           0.0   -1.255189
# 7052             24    25.000000                           0.0   -1.255189
# 7053              6    24.000000                           0.0   -1.292464
# 7054              8    19.000000                           0.0   -1.282018
# 7055             12    23.258889                           0.0   -1.331619
# 7056              9    23.258889                           0.0   -1.316554
# 7057              9    22.300000                           0.0   -1.304735
# 7058              8    23.258889                           0.0   -1.285767
# 7059             22    20.200000                           0.0   -1.255189
# 7060              8    25.000000                           0.0   -1.255010
# 7061              5    21.900000                           0.0   -1.272639
# 7062              7    24.800000                           0.0   -1.264911
# 7063              8    27.100000                           0.0   -1.300921
# 7064             24    25.100000                           0.0   -1.316959
# 7065             11    24.900000                           0.0   -1.303596
# 7066             19    20.900000                           0.0   -1.300921
# 7067              5    23.258889                           0.0   -1.284467
#
#       Pickup Long  Destination Lat  Destination Long      Rider Id  \
# 0       36.870815        -1.305249         36.822390  Rider_Id_192
# 1       36.875715        -1.288435         36.760677  Rider_Id_192
# 2       36.782203        -1.293393         36.790237  Rider_Id_192
# 3       36.868724        -1.259542         36.787118  Rider_Id_192
# 4       36.870815        -1.255189         36.782203  Rider_Id_192
# 5       36.870815        -1.331806         36.835960  Rider_Id_192
# 6       36.834501        -1.332454         36.883519  Rider_Id_192
# 7       36.889117        -1.263920         36.806930  Rider_Id_192
# 8       36.794723        -1.277007         36.823907  Rider_Id_868
# 9       36.807040        -1.346562         36.767784  Rider_Id_868
# 10      36.822971        -1.281301         36.832396  Rider_Id_868
# 11      36.757153        -1.301520         36.765846  Rider_Id_868
# 12      36.851365        -1.281301         36.832396  Rider_Id_868
# 13      36.904295        -1.288780         36.816831  Rider_Id_868
# 14      36.782203        -1.274381         36.727227  Rider_Id_868
# 15      36.782203        -1.228728         36.811530  Rider_Id_868
# 16      36.787083        -1.275311         36.813018  Rider_Id_868
# 17      36.820944        -1.317899         36.830706  Rider_Id_868
# 18      36.788458        -1.277540         36.851073  Rider_Id_868
# 19      36.778378        -1.262847         36.781805  Rider_Id_868
# 20      36.771735        -1.304735         36.784605  Rider_Id_868
# 21      36.822971        -1.276574         36.851365   Rider_Id_26
# 22      36.795063        -1.310878         36.839273   Rider_Id_26
# 23      36.847976        -1.260093         36.808869   Rider_Id_26
# 24      36.811298        -1.278272         36.777177   Rider_Id_26
# 25      36.844321        -1.326710         36.860014   Rider_Id_26
# 26      36.811298        -1.297324         36.787863   Rider_Id_26
# 27      36.830156        -1.277071         36.823109   Rider_Id_26
# 28      36.825364        -1.290894         36.822971   Rider_Id_26
# 29      36.796951        -1.255189         36.782203   Rider_Id_26
# ...           ...              ...               ...           ...
# 7038    36.912065        -1.257147         36.795063  Rider_Id_257
# 7039    36.781805        -1.229662         36.843827  Rider_Id_496
# 7040    36.788601        -1.304616         36.765857  Rider_Id_396
# 7041    36.797826        -1.273362         36.770404  Rider_Id_825
# 7042    36.919017        -1.289040         36.816494  Rider_Id_769
# 7043    36.768822        -1.276428         36.816859  Rider_Id_653
# 7044    36.792707        -1.317755         36.830370  Rider_Id_182
# 7045    36.791527        -1.255189         36.782203  Rider_Id_490
# 7046    36.819793        -1.249858         36.775497  Rider_Id_186
# 7047    36.788709        -1.258414         36.804800   Rider_Id_67
# 7048    36.795063        -1.370038         36.919017  Rider_Id_560
# 7049    36.798178        -1.252796         36.800313  Rider_Id_911
# 7050    36.782203        -1.275311         36.813018  Rider_Id_333
# 7051    36.782203        -1.270534         36.794351  Rider_Id_955
# 7052    36.782203        -1.351081         36.894806  Rider_Id_955
# 7053    36.779580        -1.291768         36.829721  Rider_Id_777
# 7054    36.822397        -1.301446         36.766138  Rider_Id_777
# 7055    36.847976        -1.344446         36.756597   Rider_Id_13
# 7056    36.700067        -1.301201         36.764868  Rider_Id_500
# 7057    36.784605        -1.263509         36.788734  Rider_Id_355
# 7058    36.787561        -1.257930         36.801967  Rider_Id_232
# 7059    36.782203        -1.319010         36.923069  Rider_Id_319
# 7060    36.804585        -1.231315         36.801686  Rider_Id_600
# 7061    36.794723        -1.277247         36.820752  Rider_Id_957
# 7062    36.813419        -1.298023         36.788650  Rider_Id_665
# 7063    36.828195        -1.272807         36.796236  Rider_Id_738
# 7064    36.700003        -1.276574         36.851365  Rider_Id_443
# 7065    36.778378        -1.330611         36.848052  Rider_Id_176
# 7066    36.828195        -1.319862         36.711032  Rider_Id_181
# 7067    36.786611        -1.296974         36.785661  Rider_Id_284
#
#       No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0              439  1511            13.3            171
# 1              439  1511            13.3            171
# 2              439  1511            13.3            171
# 3              439  1511            13.3            171
# 4              439  1511            13.3            171
# 5              439  1511            13.3            171
# 6              439  1511            13.3            171
# 7              439  1511            13.3            171
# 8              488   273            14.4             45
# 9              488   273            14.4             45
# 10             488   273            14.4             45
# 11             488   273            14.4             45
# 12             488   273            14.4             45
# 13             488   273            14.4             45
# 14             488   273            14.4             45
# 15             488   273            14.4             45
# 16             488   273            14.4             45
# 17             488   273            14.4             45
# 18             488   273            14.4             45
# 19             488   273            14.4             45
# 20             488   273            14.4             45
# 21             833   460            13.1             67
# 22             833   460            13.1             67
# 23             833   460            13.1             67
# 24             833   460            13.1             67
# 25             833   460            13.1             67
# 26             833   460            13.1             67
# 27             833   460            13.1             67
# 28             833   460            13.1             67
# 29             833   460            13.1             67
# ...            ...   ...             ...            ...
# 7038          4324  1530            13.7           1339
# 7039          5359  1895            14.1           1411
# 7040          2946  2298            14.0           1159
# 7041          2009  1760            14.0            668
# 7042          2730  2118            14.4            666
# 7043           576  1822            12.7            159
# 7044          4305  1794            13.7           1242
# 7045          5098  1850            14.4           1971
# 7046            40   880            14.7             21
# 7047            55    99            13.0              6
# 7048          2469  1652            14.1            817
# 7049          3197  1455            13.6            683
# 7050          2993  1314            14.3            532
# 7051          2595  1943            13.8            746
# 7052          2595  1943            13.8            746
# 7053          3053  1976            13.9           1159
# 7054          3053  1976            13.9           1159
# 7055          3108  3237            14.2            469
# 7056            15   251            13.5              5
# 7057          3032  1444            13.9           1047
# 7058          2862  2168            14.0           1076
# 7059          7671  2706            14.9            103
# 7060          1875  1817            14.0            822
# 7061            11   419             0.0              1
# 7062          2587  1859            12.6            723
# 7063          2849  2506            14.2            427
# 7064          3504  2234            14.6           1086
# 7065           417   136            12.8             34
# 7066            34   291            15.0              5
# 7067          2931  1170            14.2            586
#
# [7068 rows x 29 columns]

# %% [markdown]
# **Exploratory Data Analysis**

# %%
train_data.shape
# Out:
# (21201, 33)

# %%
train_data.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# min                       1.000000                         1.000000
# 25%                       8.000000                         2.000000
# 50%                      15.000000                         3.000000
# 75%                      23.000000                         5.000000
# max                      31.000000                         7.000000
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# count                      21201.000000                          21201.000000
# mean                          15.653837                              3.240225
# std                            8.798886                              1.567228
# min                            1.000000                              1.000000
# 25%                            8.000000                              2.000000
# 50%                           15.000000                              3.000000
# 75%                           23.000000                              5.000000
# max                           31.000000                              7.000000
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# count           21201.000000               21201.000000
# mean               15.653837                   3.240225
# std                 8.798886                   1.567228
# min                 1.000000                   1.000000
# 25%                 8.000000                   2.000000
# 50%                15.000000                   3.000000
# 75%                23.000000                   5.000000
# max                31.000000                   7.000000
#
#        Arrival at Destination - Day of Month  \
# count                           21201.000000
# mean                               15.653837
# std                                 8.798886
# min                                 1.000000
# 25%                                 8.000000
# 50%                                15.000000
# 75%                                23.000000
# max                                31.000000
#
#        Arrival at Destination - Weekday (Mo = 1)  Distance (KM)   Temperature  \
# count                               21201.000000   21201.000000  21201.000000
# mean                                    3.240225       9.506533     23.258889
# std                                     1.567228       5.668963      3.222006
# min                                     1.000000       1.000000     11.200000
# 25%                                     2.000000       5.000000     21.400000
# 50%                                     3.000000       8.000000     23.258889
# 75%                                     5.000000      13.000000     25.300000
# max                                     7.000000      49.000000     32.100000
#
#        Precipitation in millimeters    Pickup Lat   Pickup Long  \
# count                  21201.000000  21201.000000  21201.000000
# mean                       0.205839     -1.281470     36.811264
# std                        3.029194      0.030507      0.037473
# min                        0.000000     -1.438302     36.653621
# 25%                        0.000000     -1.300921     36.784605
# 50%                        0.000000     -1.279395     36.807040
# 75%                        0.000000     -1.257147     36.829741
# max                       99.100000     -1.147170     36.991046
#
#        Destination Lat  Destination Long  Time from Pickup to Arrival  \
# count     21201.000000      21201.000000                 21201.000000
# mean         -1.282581         36.811220                  1556.920947
# std           0.034824          0.044721                   987.270788
# min          -1.430298         36.606594                     1.000000
# 25%          -1.301201         36.785661                   882.000000
# 50%          -1.284382         36.808002                  1369.000000
# 75%          -1.261177         36.829477                  2040.000000
# max          -1.030225         37.016779                  7883.000000
#
#        No_Of_Orders           Age  Average_Rating  No_of_Ratings
# count  21201.000000  21201.000000    21201.000000   21201.000000
# mean    1692.423706    984.742842       13.882520     341.067119
# std     1574.308302    646.652835        0.916071     402.867746
# min        2.000000     96.000000        0.000000       0.000000
# 25%      557.000000    495.000000       13.600000      61.000000
# 50%     1212.000000    872.000000       14.000000     161.000000
# 75%     2311.000000   1236.000000       14.300000     495.000000
# max     9756.000000   3764.000000       15.200000    2298.000000

# %% [markdown]
# Lets look at the distribution of our target variable 'Time from Pickup to Arrival'

# %%
figsize(8, 8)

# Rename the score 
#df = train_data.rename(columns = {'ENERGY STAR Score': 'score'})

# Histogram of the Energy Star Score
plt.style.use('fivethirtyeight')
plt.hist(train_data['Time from Pickup to Arrival'].dropna(), bins = 100, edgecolor = 'k');
plt.xlabel(''); plt.ylabel('Time in seconds'); 
plt.title('Time from Pickup to Arrival Distribution');

# %%
def min_max_values(col):
    ''' This function takes the column name as the argument and returns
    the top and bottom observation in that argument 
    '''
    top = train_data[col].idxmax()
    top_obs = pd.DataFrame(train_data.loc[top])
    
    bottom = train_data[col].idxmin()
    bot_obs = pd.DataFrame(train_data.loc[bottom])
    
    min_max_obs = pd.concat([top_obs, bot_obs], axis = 1)
    
    return min_max_obs

# %%
min_max_values('Time from Pickup to Arrival')
# Out:
#                                                    10585          1911
# Order No                                   Order_No_5837  Order_No_4785
# User Id                                      User_Id_658    User_Id_393
# Vehicle Type                                        Bike           Bike
# Platform Type                                          2              3
# Personal or Business                            Personal       Business
# Placement - Day of Month                              30             23
# Placement - Weekday (Mo = 1)                           1              3
# Placement - Time                                10:07:30       10:49:47
# Confirmation - Day of Month                           30             23
# Confirmation - Weekday (Mo = 1)                        1              3
# Confirmation - Time                             10:08:15       10:49:55
# Arrival at Pickup - Day of Month                      30             23
# Arrival at Pickup - Weekday (Mo = 1)                   1              3
# Arrival at Pickup - Time                        10:35:12       10:52:56
# Pickup - Day of Month                                 30             23
# Pickup - Weekday (Mo = 1)                              1              3
# Pickup - Time                                   10:37:36       11:18:30
# Arrival at Destination - Day of Month                 30             23
# Arrival at Destination - Weekday (Mo = 1)              1              3
# Arrival at Destination - Time                   12:48:59       11:18:31
# Distance (KM)                                         27              5
# Temperature                                         22.5        23.2589
# Precipitation in millimeters                           0              0
# Pickup Lat                                      -1.28279       -1.31671
# Pickup Long                                      36.7689        36.8302
# Destination Lat                                 -1.15608       -1.30779
# Destination Long                                 36.7067        36.8443
# Rider Id                                    Rider_Id_857   Rider_Id_523
# Time from Pickup to Arrival                         7883              1
# No_Of_Orders                                         583            928
# Age                                                  742            494
# Average_Rating                                      13.7           14.3
# No_of_Ratings                                         52             43

# %%
train_num_floats = train_data.select_dtypes(include =['float64'])
train_num_floats.head()
# Out:
#    Temperature  Precipitation in millimeters  Pickup Lat  Pickup Long  \
# 0         20.4                           0.0   -1.317755    36.830370
# 1         24.5                           0.0   -1.326774    36.787807
# 2         24.7                           0.0   -1.255189    36.782203
# 3         15.2                           0.0   -1.290315    36.757377
# 4         19.2                           0.0   -1.273524    36.799220
#
#    Destination Lat  Destination Long  Average_Rating
# 0        -1.300406         36.829741            13.8
# 1        -1.356237         36.904295            13.8
# 2        -1.273412         36.818206            13.8
# 3        -1.223520         36.802061            13.8
# 4        -1.300431         36.752427            13.8

# %%
train_num_floats.hist(bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E811C30C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E811C8E0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E811CB5A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E811CF1438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E811D1EDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E8121BA7B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E811C5D978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E811B92748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E811B92A90>]],
#       dtype=object)

# %%
train_num = train_data.select_dtypes(include =['float64', 'int64'])

# %%
train_corr = train_num.corr()['Time from Pickup to Arrival'][:-1]

# %%
train_corr
# Out:
# Platform Type                               -0.003827
# Placement - Day of Month                    -0.014710
# Placement - Weekday (Mo = 1)                 0.009693
# Confirmation - Day of Month                 -0.014701
# Confirmation - Weekday (Mo = 1)              0.009744
# Arrival at Pickup - Day of Month            -0.014701
# Arrival at Pickup - Weekday (Mo = 1)         0.009744
# Pickup - Day of Month                       -0.014701
# Pickup - Weekday (Mo = 1)                    0.009744
# Arrival at Destination - Day of Month       -0.014701
# Arrival at Destination - Weekday (Mo = 1)    0.009744
# Distance (KM)                                0.580608
# Temperature                                  0.005772
# Precipitation in millimeters                 0.005495
# Pickup Lat                                  -0.053823
# Pickup Long                                  0.060285
# Destination Lat                             -0.061872
# Destination Long                             0.070425
# Time from Pickup to Arrival                  1.000000
# No_Of_Orders                                -0.041608
# Age                                         -0.007969
# Average_Rating                              -0.042559
# Name: Time from Pickup to Arrival, dtype: float64

# %%
#correlation plots using pairplots
for i in range(0, len(train_num.columns),5):
    sns.pairplot(train_num, y_vars=['Time from Pickup to Arrival'],x_vars=train_num.columns[i:i+5])

# %%
#box-plot (categorical variables)

box1 = sns.boxplot(x='Pickup - Day of Month', y='Time from Pickup to Arrival', data=train, saturation=10, width=1)

# %%
#box-plot (categorical variables)

box2 = sns.boxplot(x='Distance (KM)', y='Time from Pickup to Arrival', data=train, saturation=10, width=1)

# %%
#box-plot (categorical variables)

box3 = sns.boxplot(x='Pickup - Day of Month', y='Time from Pickup to Arrival', data=train, saturation=10, width=1)

# %%
#Regression Plot

sns.regplot(train_num['Distance (KM)'], train_num['Time from Pickup to Arrival'])

# %% [markdown]
# Feature engineering and feature selection

# %% [markdown]
# Change all cyclical data columns, Time, Weekday and day of month

# %%
#Change time to float
train_data['Placement - Time'] = pd.to_timedelta(train_data['Placement - Time'])
train_data['Placement - Time'] = train_data['Placement - Time'] / pd.offsets.Minute(60)
train_data['Confirmation - Time'] = pd.to_timedelta(train_data['Confirmation - Time'])
train_data['Confirmation - Time'] = train_data['Confirmation - Time'] / pd.offsets.Minute(60)
train_data['Arrival at Destination - Time'] = pd.to_timedelta(train_data['Arrival at Destination - Time'])
train_data['Arrival at Destination - Time'] = train_data['Arrival at Destination - Time'] / pd.offsets.Minute(60)
train_data['Pickup - Time'] = pd.to_timedelta(train_data['Pickup - Time'])
train_data['Pickup - Time'] = train_data['Pickup - Time'] / pd.offsets.Minute(60)
train_data['Arrival at Pickup - Time'] = pd.to_timedelta(train_data['Arrival at Pickup - Time'])
train_data['Arrival at Pickup - Time'] = train_data['Arrival at Pickup - Time'] / pd.offsets.Minute(60)
test_data['Arrival at Pickup - Time'] = pd.to_timedelta(test_data['Arrival at Pickup - Time'])
test_data['Arrival at Pickup - Time'] = test_data['Arrival at Pickup - Time'] / pd.offsets.Minute(60)
test_data['Placement - Time'] = pd.to_timedelta(test_data['Placement - Time'])
test_data['Placement - Time'] = test_data['Placement - Time'] / pd.offsets.Minute(60)
test_data['Confirmation - Time'] = pd.to_timedelta(test_data['Confirmation - Time'])
test_data['Confirmation - Time'] = test_data['Confirmation - Time'] / pd.offsets.Minute(60)
test_data['Pickup - Time'] = pd.to_timedelta(test_data['Pickup - Time'])
test_data['Pickup - Time'] = test_data['Pickup - Time'] / pd.offsets.Minute(60)

# %%
#Change time to x,y to rightfully reflect a cycle form
train_data['Placement_time_x']=np.sin(2.*np.pi*train_data['Placement - Time']/24.)
train_data['Placement_time_y']=np.cos(2.*np.pi*train_data['Placement - Time']/24.)
train_data['Confirmation - time_x']=np.sin(2.*np.pi*train_data['Confirmation - Time']/24.)
train_data['Confirmation - time_y']=np.cos(2.*np.pi*train_data['Confirmation - Time']/24.)
train_data['Arrival at Destination - time_x']=np.sin(2.*np.pi*train_data['Arrival at Destination - Time']/24.)
train_data['Arrival at Destination - time_y']=np.cos(2.*np.pi*train_data['Arrival at Destination - Time']/24.)
train_data['Pickup - time_x']=np.sin(2.*np.pi*train_data['Pickup - Time']/24.)
train_data['Pickup - time_y']=np.cos(2.*np.pi*train_data['Pickup - Time']/24.)
train_data['Arrival at Pickup - time_x']=np.sin(2.*np.pi*train_data['Arrival at Pickup - Time']/24.)
train_data['Arrival at Pickup - time_y']=np.cos(2.*np.pi*train_data['Arrival at Pickup - Time']/24.)
test_data['Arrival at Pickup - time_x']=np.sin(2.*np.pi*test_data['Arrival at Pickup - Time']/24.)
test_data['Arrival at Pickup - time_y']=np.cos(2.*np.pi*test_data['Arrival at Pickup - Time']/24.)
test_data['Placement_time_x']=np.sin(2.*np.pi*train_data['Placement - Time']/24.)
test_data['Placement_time_y']=np.cos(2.*np.pi*train_data['Placement - Time']/24.)
test_data['Confirmation - time_x']=np.sin(2.*np.pi*test_data['Confirmation - Time']/24.)
test_data['Confirmation - time_y']=np.cos(2.*np.pi*test_data['Confirmation - Time']/24.)
test_data['Pickup - time_x']=np.sin(2.*np.pi*test_data['Pickup - Time']/24.)
test_data['Pickup - time_y']=np.cos(2.*np.pi*test_data['Pickup - Time']/24.)

# %%
train_data.drop(['Placement - Time', 'Confirmation - Time', 'Arrival at Destination - Time', 'Pickup - Time', 'Arrival at Pickup - Time'], axis=1, inplace=True)
test_data.drop(['Arrival at Pickup - Time', 'Placement - Time', 'Confirmation - Time', 'Pickup - Time'], axis=1, inplace=True)

# %%
train_data.plot.scatter('Placement_time_x', 'Placement_time_y').set_aspect('equal');

# %%
#create feature speed
train_data['speed'] = train_data['Distance (KM)'] / train_data['Time from Pickup to Arrival']
train_data.head().T
# Out:
#                                                        0               1  \
# Order No                                   Order_No_4211  Order_No_27440
# User Id                                      User_Id_633    User_Id_2642
# Vehicle Type                                        Bike            Bike
# Platform Type                                          3               3
# Personal or Business                            Business        Personal
# Placement - Day of Month                               9              18
# Placement - Weekday (Mo = 1)                           5               5
# Confirmation - Day of Month                            9              18
# Confirmation - Weekday (Mo = 1)                        5               5
# Arrival at Pickup - Day of Month                       9              18
# Arrival at Pickup - Weekday (Mo = 1)                   5               5
# Pickup - Day of Month                                  9              18
# Pickup - Weekday (Mo = 1)                              5               5
# Arrival at Destination - Day of Month                  9              18
# Arrival at Destination - Weekday (Mo = 1)              5               5
# Distance (KM)                                          4              20
# Temperature                                         20.4            24.5
# Precipitation in millimeters                           0               0
# Pickup Lat                                      -1.31775        -1.32677
# Pickup Long                                      36.8304         36.7878
# Destination Lat                                 -1.30041        -1.35624
# Destination Long                                 36.8297         36.9043
# Rider Id                                    Rider_Id_432    Rider_Id_432
# Time from Pickup to Arrival                          745            2886
# No_Of_Orders                                        1637            1637
# Age                                                 1309            1309
# Average_Rating                                      13.8            13.8
# No_of_Ratings                                        549             549
# Placement_time_x                                0.588609       -0.822351
# Placement_time_y                               -0.808418       -0.568981
# Confirmation - time_x                           0.572981       -0.822889
# Confirmation - time_y                          -0.819569       -0.568203
# Arrival at Destination - time_x                 0.342362       -0.967837
# Arrival at Destination - time_y                -0.939568       -0.251577
# Pickup - time_x                                 0.392738       -0.894187
# Pickup - time_y                                 -0.91965       -0.447694
# Arrival at Pickup - time_x                      0.481817       -0.881441
# Arrival at Pickup - time_y                     -0.876272       -0.472294
# speed                                         0.00536913      0.00693001
#
#                                                         2               3  \
# Order No                                   Order_No_14170  Order_No_21727
# User Id                                      User_Id_3339    User_Id_3523
# Vehicle Type                                         Bike            Bike
# Platform Type                                           3               3
# Personal or Business                             Business        Personal
# Placement - Day of Month                               31               2
# Placement - Weekday (Mo = 1)                            5               2
# Confirmation - Day of Month                            31               2
# Confirmation - Weekday (Mo = 1)                         5               2
# Arrival at Pickup - Day of Month                       31               2
# Arrival at Pickup - Weekday (Mo = 1)                    5               2
# Pickup - Day of Month                                  31               2
# Pickup - Weekday (Mo = 1)                               5               2
# Arrival at Destination - Day of Month                  31               2
# Arrival at Destination - Weekday (Mo = 1)               5               2
# Distance (KM)                                           6              18
# Temperature                                          24.7            15.2
# Precipitation in millimeters                            0               0
# Pickup Lat                                       -1.25519        -1.29031
# Pickup Long                                       36.7822         36.7574
# Destination Lat                                  -1.27341        -1.22352
# Destination Long                                  36.8182         36.8021
# Rider Id                                     Rider_Id_432    Rider_Id_432
# Time from Pickup to Arrival                          2615            2986
# No_Of_Orders                                         1637            1637
# Age                                                  1309            1309
# Average_Rating                                       13.8            13.8
# No_of_Ratings                                         549             549
# Placement_time_x                                -0.223605        0.950832
# Placement_time_y                                 -0.97468       -0.309709
# Confirmation - time_x                           -0.312404        0.950403
# Confirmation - time_y                           -0.949949       -0.311022
# Arrival at Destination - time_x                 -0.561783        0.797233
# Arrival at Destination - time_y                 -0.827285       -0.603672
# Pickup - time_x                                 -0.395278        0.908569
# Pickup - time_y                                 -0.918561       -0.417735
# Arrival at Pickup - time_x                      -0.342157        0.914607
# Arrival at Pickup - time_y                      -0.939643       -0.404344
# speed                                          0.00229446      0.00602813
#
#                                                        4
# Order No                                   Order_No_8301
# User Id                                       User_Id_87
# Vehicle Type                                        Bike
# Platform Type                                          2
# Personal or Business                            Personal
# Placement - Day of Month                              22
# Placement - Weekday (Mo = 1)                           2
# Confirmation - Day of Month                           22
# Confirmation - Weekday (Mo = 1)                        2
# Arrival at Pickup - Day of Month                      22
# Arrival at Pickup - Weekday (Mo = 1)                   2
# Pickup - Day of Month                                 22
# Pickup - Weekday (Mo = 1)                              2
# Arrival at Destination - Day of Month                 22
# Arrival at Destination - Weekday (Mo = 1)              2
# Distance (KM)                                          7
# Temperature                                         19.2
# Precipitation in millimeters                           0
# Pickup Lat                                      -1.27352
# Pickup Long                                      36.7992
# Destination Lat                                 -1.30043
# Destination Long                                 36.7524
# Rider Id                                    Rider_Id_432
# Time from Pickup to Arrival                         1602
# No_Of_Orders                                        1637
# Age                                                 1309
# Average_Rating                                      13.8
# No_of_Ratings                                        549
# Placement_time_x                                0.338054
# Placement_time_y                               -0.941127
# Confirmation - time_x                           0.332161
# Confirmation - time_y                          -0.943223
# Arrival at Destination - time_x                 0.146227
# Arrival at Destination - time_y                -0.989251
# Pickup - time_x                                 0.260224
# Pickup - time_y                                -0.965548
# Arrival at Pickup - time_x                      0.275637
# Arrival at Pickup - time_y                     -0.961262
# speed                                         0.00436954

# %% [markdown]
# Drop columns that are unique identifier, as we do not need them.
# Drop Vehicle type because we only have one type of vehicle.

# %%
train_data.drop(['Order No', 'User Id', 'Vehicle Type', 'Rider Id'], axis = 1, inplace = True)
test_data.drop(['Order No', 'User Id', 'Vehicle Type', 'Rider Id'], axis = 1, inplace = True)

# %%
#get correlated values
plt.figure(figsize = (15,15))
sns.heatmap(train_data.corr())

# %% [markdown]
# We use a logic test with a significance value of 5%

# %%
corrs = train_data.corr()['Time from Pickup to Arrival'].sort_values(ascending=False)

# %%
from scipy.stats import pearsonr

# Build a dictionary of correlation coefficients and p-values
dict_cp = {}

column_titles = [col for col in corrs.index if col!= 'Time from Pickup to Arrival']
for col in column_titles:
    p_val = round(pearsonr(train_data[col], train_data['Time from Pickup to Arrival'])[1],6)
    dict_cp[col] = {'Correlation_Coefficient':corrs[col],
                    'P_Value':p_val}
    
df_cp = pd.DataFrame(dict_cp).T
df_cp_sorted = df_cp.sort_values('P_Value')
df_cp_sorted[df_cp_sorted['P_Value']<0.5]
# Out:
#                                            Correlation_Coefficient   P_Value
# Distance (KM)                                             0.580608  0.000000
# Destination Lat                                          -0.061872  0.000000
# Pickup Lat                                               -0.053823  0.000000
# Average_Rating                                           -0.042559  0.000000
# No_Of_Orders                                             -0.041608  0.000000
# Arrival at Destination - time_x                          -0.116724  0.000000
# speed                                                    -0.188162  0.000000
# Arrival at Destination - time_y                           0.083636  0.000000
# Destination Long                                          0.070425  0.000000
# Pickup Long                                               0.060285  0.000000
# Arrival at Pickup - time_x                               -0.023330  0.000681
# Placement_time_y                                         -0.022370  0.001125
# Confirmation - time_y                                    -0.017780  0.009629
# Pickup - time_x                                          -0.017662  0.010119
# Placement - Day of Month                                 -0.014710  0.032205
# Arrival at Pickup - Day of Month                         -0.014701  0.032312
# Confirmation - Day of Month                              -0.014701  0.032312
# Arrival at Destination - Day of Month                    -0.014701  0.032312
# Pickup - Day of Month                                    -0.014701  0.032312
# Confirmation - time_x                                    -0.010038  0.143851
# Confirmation - Weekday (Mo = 1)                           0.009744  0.155959
# Arrival at Destination - Weekday (Mo = 1)                 0.009744  0.155959
# Arrival at Pickup - Weekday (Mo = 1)                      0.009744  0.155959
# Pickup - Weekday (Mo = 1)                                 0.009744  0.155959
# Placement - Weekday (Mo = 1)                              0.009693  0.158160
# Arrival at Pickup - time_y                               -0.009270  0.177091
# Pickup - time_y                                          -0.009269  0.177161
# Age                                                      -0.007969  0.245953
# Temperature                                               0.005772  0.400716
# No_of_Ratings                                             0.005609  0.414128
# Placement_time_x                                         -0.005547  0.419320
# Precipitation in millimeters                              0.005495  0.423689

# %%
# The dependent variable remains the same:
y_name = 'Time from Pickup to Arrival'
y_data = train_data[y_name]  # y_name = 'Loan_Size'

# Model building - Independent Variable (IV) DataFrame
X_names = list(df_cp[df_cp['P_Value'] < 0.5].index)
X_data = train_data[X_names]

# %% [markdown]
# Predictor variables pairs which have a high correlation with each other

# %%
# Create the correlation matrix
corr = X_data.corr()

# Find rows and columnd where correlation coefficients > 0.9 or <-0.9
corr[np.abs(corr) > 0.9]
# Out:
#                                            Distance (KM)  \
# Distance (KM)                                        1.0
# Arrival at Destination - time_y                      NaN
# Destination Long                                     NaN
# Pickup Long                                          NaN
# Confirmation - Weekday (Mo = 1)                      NaN
# Arrival at Pickup - Weekday (Mo = 1)                 NaN
# Pickup - Weekday (Mo = 1)                            NaN
# Arrival at Destination - Weekday (Mo = 1)            NaN
# Placement - Weekday (Mo = 1)                         NaN
# Temperature                                          NaN
# No_of_Ratings                                        NaN
# Precipitation in millimeters                         NaN
# Placement_time_x                                     NaN
# Age                                                  NaN
# Pickup - time_y                                      NaN
# Arrival at Pickup - time_y                           NaN
# Confirmation - time_x                                NaN
# Confirmation - Day of Month                          NaN
# Arrival at Pickup - Day of Month                     NaN
# Pickup - Day of Month                                NaN
# Arrival at Destination - Day of Month                NaN
# Placement - Day of Month                             NaN
# Pickup - time_x                                      NaN
# Confirmation - time_y                                NaN
# Placement_time_y                                     NaN
# Arrival at Pickup - time_x                           NaN
# No_Of_Orders                                         NaN
# Average_Rating                                       NaN
# Pickup Lat                                           NaN
# Destination Lat                                      NaN
# Arrival at Destination - time_x                      NaN
# speed                                                NaN
#
#                                            Arrival at Destination - time_y  \
# Distance (KM)                                                          NaN
# Arrival at Destination - time_y                                   1.000000
# Destination Long                                                       NaN
# Pickup Long                                                            NaN
# Confirmation - Weekday (Mo = 1)                                        NaN
# Arrival at Pickup - Weekday (Mo = 1)                                   NaN
# Pickup - Weekday (Mo = 1)                                              NaN
# Arrival at Destination - Weekday (Mo = 1)                              NaN
# Placement - Weekday (Mo = 1)                                           NaN
# Temperature                                                            NaN
# No_of_Ratings                                                          NaN
# Precipitation in millimeters                                           NaN
# Placement_time_x                                                       NaN
# Age                                                                    NaN
# Pickup - time_y                                                   0.980490
# Arrival at Pickup - time_y                                        0.960854
# Confirmation - time_x                                                  NaN
# Confirmation - Day of Month                                            NaN
# Arrival at Pickup - Day of Month                                       NaN
# Pickup - Day of Month                                                  NaN
# Arrival at Destination - Day of Month                                  NaN
# Placement - Day of Month                                               NaN
# Pickup - time_x                                                        NaN
# Confirmation - time_y                                             0.928085
# Placement_time_y                                                       NaN
# Arrival at Pickup - time_x                                             NaN
# No_Of_Orders                                                           NaN
# Average_Rating                                                         NaN
# Pickup Lat                                                             NaN
# Destination Lat                                                        NaN
# Arrival at Destination - time_x                                        NaN
# speed                                                                  NaN
#
#                                            Destination Long  Pickup Long  \
# Distance (KM)                                           NaN          NaN
# Arrival at Destination - time_y                         NaN          NaN
# Destination Long                                        1.0          NaN
# Pickup Long                                             NaN          1.0
# Confirmation - Weekday (Mo = 1)                         NaN          NaN
# Arrival at Pickup - Weekday (Mo = 1)                    NaN          NaN
# Pickup - Weekday (Mo = 1)                               NaN          NaN
# Arrival at Destination - Weekday (Mo = 1)               NaN          NaN
# Placement - Weekday (Mo = 1)                            NaN          NaN
# Temperature                                             NaN          NaN
# No_of_Ratings                                           NaN          NaN
# Precipitation in millimeters                            NaN          NaN
# Placement_time_x                                        NaN          NaN
# Age                                                     NaN          NaN
# Pickup - time_y                                         NaN          NaN
# Arrival at Pickup - time_y                              NaN          NaN
# Confirmation - time_x                                   NaN          NaN
# Confirmation - Day of Month                             NaN          NaN
# Arrival at Pickup - Day of Month                        NaN          NaN
# Pickup - Day of Month                                   NaN          NaN
# Arrival at Destination - Day of Month                   NaN          NaN
# Placement - Day of Month                                NaN          NaN
# Pickup - time_x                                         NaN          NaN
# Confirmation - time_y                                   NaN          NaN
# Placement_time_y                                        NaN          NaN
# Arrival at Pickup - time_x                              NaN          NaN
# No_Of_Orders                                            NaN          NaN
# Average_Rating                                          NaN          NaN
# Pickup Lat                                              NaN          NaN
# Destination Lat                                         NaN          NaN
# Arrival at Destination - time_x                         NaN          NaN
# speed                                                   NaN          NaN
#
#                                            Confirmation - Weekday (Mo = 1)  \
# Distance (KM)                                                          NaN
# Arrival at Destination - time_y                                        NaN
# Destination Long                                                       NaN
# Pickup Long                                                            NaN
# Confirmation - Weekday (Mo = 1)                                   1.000000
# Arrival at Pickup - Weekday (Mo = 1)                              1.000000
# Pickup - Weekday (Mo = 1)                                         1.000000
# Arrival at Destination - Weekday (Mo = 1)                         1.000000
# Placement - Weekday (Mo = 1)                                      0.999952
# Temperature                                                            NaN
# No_of_Ratings                                                          NaN
# Precipitation in millimeters                                           NaN
# Placement_time_x                                                       NaN
# Age                                                                    NaN
# Pickup - time_y                                                        NaN
# Arrival at Pickup - time_y                                             NaN
# Confirmation - time_x                                                  NaN
# Confirmation - Day of Month                                            NaN
# Arrival at Pickup - Day of Month                                       NaN
# Pickup - Day of Month                                                  NaN
# Arrival at Destination - Day of Month                                  NaN
# Placement - Day of Month                                               NaN
# Pickup - time_x                                                        NaN
# Confirmation - time_y                                                  NaN
# Placement_time_y                                                       NaN
# Arrival at Pickup - time_x                                             NaN
# No_Of_Orders                                                           NaN
# Average_Rating                                                         NaN
# Pickup Lat                                                             NaN
# Destination Lat                                                        NaN
# Arrival at Destination - time_x                                        NaN
# speed                                                                  NaN
#
#                                            Arrival at Pickup - Weekday (Mo = 1)  \
# Distance (KM)                                                               NaN
# Arrival at Destination - time_y                                             NaN
# Destination Long                                                            NaN
# Pickup Long                                                                 NaN
# Confirmation - Weekday (Mo = 1)                                        1.000000
# Arrival at Pickup - Weekday (Mo = 1)                                   1.000000
# Pickup - Weekday (Mo = 1)                                              1.000000
# Arrival at Destination - Weekday (Mo = 1)                              1.000000
# Placement - Weekday (Mo = 1)                                           0.999952
# Temperature                                                                 NaN
# No_of_Ratings                                                               NaN
# Precipitation in millimeters                                                NaN
# Placement_time_x                                                            NaN
# Age                                                                         NaN
# Pickup - time_y                                                             NaN
# Arrival at Pickup - time_y                                                  NaN
# Confirmation - time_x                                                       NaN
# Confirmation - Day of Month                                                 NaN
# Arrival at Pickup - Day of Month                                            NaN
# Pickup - Day of Month                                                       NaN
# Arrival at Destination - Day of Month                                       NaN
# Placement - Day of Month                                                    NaN
# Pickup - time_x                                                             NaN
# Confirmation - time_y                                                       NaN
# Placement_time_y                                                            NaN
# Arrival at Pickup - time_x                                                  NaN
# No_Of_Orders                                                                NaN
# Average_Rating                                                              NaN
# Pickup Lat                                                                  NaN
# Destination Lat                                                             NaN
# Arrival at Destination - time_x                                             NaN
# speed                                                                       NaN
#
#                                            Pickup - Weekday (Mo = 1)  \
# Distance (KM)                                                    NaN
# Arrival at Destination - time_y                                  NaN
# Destination Long                                                 NaN
# Pickup Long                                                      NaN
# Confirmation - Weekday (Mo = 1)                             1.000000
# Arrival at Pickup - Weekday (Mo = 1)                        1.000000
# Pickup - Weekday (Mo = 1)                                   1.000000
# Arrival at Destination - Weekday (Mo = 1)                   1.000000
# Placement - Weekday (Mo = 1)                                0.999952
# Temperature                                                      NaN
# No_of_Ratings                                                    NaN
# Precipitation in millimeters                                     NaN
# Placement_time_x                                                 NaN
# Age                                                              NaN
# Pickup - time_y                                                  NaN
# Arrival at Pickup - time_y                                       NaN
# Confirmation - time_x                                            NaN
# Confirmation - Day of Month                                      NaN
# Arrival at Pickup - Day of Month                                 NaN
# Pickup - Day of Month                                            NaN
# Arrival at Destination - Day of Month                            NaN
# Placement - Day of Month                                         NaN
# Pickup - time_x                                                  NaN
# Confirmation - time_y                                            NaN
# Placement_time_y                                                 NaN
# Arrival at Pickup - time_x                                       NaN
# No_Of_Orders                                                     NaN
# Average_Rating                                                   NaN
# Pickup Lat                                                       NaN
# Destination Lat                                                  NaN
# Arrival at Destination - time_x                                  NaN
# speed                                                            NaN
#
#                                            Arrival at Destination - Weekday (Mo = 1)  \
# Distance (KM)                                                                    NaN
# Arrival at Destination - time_y                                                  NaN
# Destination Long                                                                 NaN
# Pickup Long                                                                      NaN
# Confirmation - Weekday (Mo = 1)                                             1.000000
# Arrival at Pickup - Weekday (Mo = 1)                                        1.000000
# Pickup - Weekday (Mo = 1)                                                   1.000000
# Arrival at Destination - Weekday (Mo = 1)                                   1.000000
# Placement - Weekday (Mo = 1)                                                0.999952
# Temperature                                                                      NaN
# No_of_Ratings                                                                    NaN
# Precipitation in millimeters                                                     NaN
# Placement_time_x                                                                 NaN
# Age                                                                              NaN
# Pickup - time_y                                                                  NaN
# Arrival at Pickup - time_y                                                       NaN
# Confirmation - time_x                                                            NaN
# Confirmation - Day of Month                                                      NaN
# Arrival at Pickup - Day of Month                                                 NaN
# Pickup - Day of Month                                                            NaN
# Arrival at Destination - Day of Month                                            NaN
# Placement - Day of Month                                                         NaN
# Pickup - time_x                                                                  NaN
# Confirmation - time_y                                                            NaN
# Placement_time_y                                                                 NaN
# Arrival at Pickup - time_x                                                       NaN
# No_Of_Orders                                                                     NaN
# Average_Rating                                                                   NaN
# Pickup Lat                                                                       NaN
# Destination Lat                                                                  NaN
# Arrival at Destination - time_x                                                  NaN
# speed                                                                            NaN
#
#                                            Placement - Weekday (Mo = 1)  \
# Distance (KM)                                                       NaN
# Arrival at Destination - time_y                                     NaN
# Destination Long                                                    NaN
# Pickup Long                                                         NaN
# Confirmation - Weekday (Mo = 1)                                0.999952
# Arrival at Pickup - Weekday (Mo = 1)                           0.999952
# Pickup - Weekday (Mo = 1)                                      0.999952
# Arrival at Destination - Weekday (Mo = 1)                      0.999952
# Placement - Weekday (Mo = 1)                                   1.000000
# Temperature                                                         NaN
# No_of_Ratings                                                       NaN
# Precipitation in millimeters                                        NaN
# Placement_time_x                                                    NaN
# Age                                                                 NaN
# Pickup - time_y                                                     NaN
# Arrival at Pickup - time_y                                          NaN
# Confirmation - time_x                                               NaN
# Confirmation - Day of Month                                         NaN
# Arrival at Pickup - Day of Month                                    NaN
# Pickup - Day of Month                                               NaN
# Arrival at Destination - Day of Month                               NaN
# Placement - Day of Month                                            NaN
# Pickup - time_x                                                     NaN
# Confirmation - time_y                                               NaN
# Placement_time_y                                                    NaN
# Arrival at Pickup - time_x                                          NaN
# No_Of_Orders                                                        NaN
# Average_Rating                                                      NaN
# Pickup Lat                                                          NaN
# Destination Lat                                                     NaN
# Arrival at Destination - time_x                                     NaN
# speed                                                               NaN
#
#                                            Temperature  No_of_Ratings  \
# Distance (KM)                                      NaN            NaN
# Arrival at Destination - time_y                    NaN            NaN
# Destination Long                                   NaN            NaN
# Pickup Long                                        NaN            NaN
# Confirmation - Weekday (Mo = 1)                    NaN            NaN
# Arrival at Pickup - Weekday (Mo = 1)               NaN            NaN
# Pickup - Weekday (Mo = 1)                          NaN            NaN
# Arrival at Destination - Weekday (Mo = 1)          NaN            NaN
# Placement - Weekday (Mo = 1)                       NaN            NaN
# Temperature                                        1.0            NaN
# No_of_Ratings                                      NaN            1.0
# Precipitation in millimeters                       NaN            NaN
# Placement_time_x                                   NaN            NaN
# Age                                                NaN            NaN
# Pickup - time_y                                    NaN            NaN
# Arrival at Pickup - time_y                         NaN            NaN
# Confirmation - time_x                              NaN            NaN
# Confirmation - Day of Month                        NaN            NaN
# Arrival at Pickup - Day of Month                   NaN            NaN
# Pickup - Day of Month                              NaN            NaN
# Arrival at Destination - Day of Month              NaN            NaN
# Placement - Day of Month                           NaN            NaN
# Pickup - time_x                                    NaN            NaN
# Confirmation - time_y                              NaN            NaN
# Placement_time_y                                   NaN            NaN
# Arrival at Pickup - time_x                         NaN            NaN
# No_Of_Orders                                       NaN            NaN
# Average_Rating                                     NaN            NaN
# Pickup Lat                                         NaN            NaN
# Destination Lat                                    NaN            NaN
# Arrival at Destination - time_x                    NaN            NaN
# speed                                              NaN            NaN
#
#                                            Precipitation in millimeters  \
# Distance (KM)                                                       NaN
# Arrival at Destination - time_y                                     NaN
# Destination Long                                                    NaN
# Pickup Long                                                         NaN
# Confirmation - Weekday (Mo = 1)                                     NaN
# Arrival at Pickup - Weekday (Mo = 1)                                NaN
# Pickup - Weekday (Mo = 1)                                           NaN
# Arrival at Destination - Weekday (Mo = 1)                           NaN
# Placement - Weekday (Mo = 1)                                        NaN
# Temperature                                                         NaN
# No_of_Ratings                                                       NaN
# Precipitation in millimeters                                        1.0
# Placement_time_x                                                    NaN
# Age                                                                 NaN
# Pickup - time_y                                                     NaN
# Arrival at Pickup - time_y                                          NaN
# Confirmation - time_x                                               NaN
# Confirmation - Day of Month                                         NaN
# Arrival at Pickup - Day of Month                                    NaN
# Pickup - Day of Month                                               NaN
# Arrival at Destination - Day of Month                               NaN
# Placement - Day of Month                                            NaN
# Pickup - time_x                                                     NaN
# Confirmation - time_y                                               NaN
# Placement_time_y                                                    NaN
# Arrival at Pickup - time_x                                          NaN
# No_Of_Orders                                                        NaN
# Average_Rating                                                      NaN
# Pickup Lat                                                          NaN
# Destination Lat                                                     NaN
# Arrival at Destination - time_x                                     NaN
# speed                                                               NaN
#
#                                            Placement_time_x  Age  \
# Distance (KM)                                           NaN  NaN
# Arrival at Destination - time_y                         NaN  NaN
# Destination Long                                        NaN  NaN
# Pickup Long                                             NaN  NaN
# Confirmation - Weekday (Mo = 1)                         NaN  NaN
# Arrival at Pickup - Weekday (Mo = 1)                    NaN  NaN
# Pickup - Weekday (Mo = 1)                               NaN  NaN
# Arrival at Destination - Weekday (Mo = 1)               NaN  NaN
# Placement - Weekday (Mo = 1)                            NaN  NaN
# Temperature                                             NaN  NaN
# No_of_Ratings                                           NaN  NaN
# Precipitation in millimeters                            NaN  NaN
# Placement_time_x                                   1.000000  NaN
# Age                                                     NaN  1.0
# Pickup - time_y                                         NaN  NaN
# Arrival at Pickup - time_y                              NaN  NaN
# Confirmation - time_x                              0.993892  NaN
# Confirmation - Day of Month                             NaN  NaN
# Arrival at Pickup - Day of Month                        NaN  NaN
# Pickup - Day of Month                                   NaN  NaN
# Arrival at Destination - Day of Month                   NaN  NaN
# Placement - Day of Month                                NaN  NaN
# Pickup - time_x                                    0.986032  NaN
# Confirmation - time_y                                   NaN  NaN
# Placement_time_y                                        NaN  NaN
# Arrival at Pickup - time_x                         0.990022  NaN
# No_Of_Orders                                            NaN  NaN
# Average_Rating                                          NaN  NaN
# Pickup Lat                                              NaN  NaN
# Destination Lat                                         NaN  NaN
# Arrival at Destination - time_x                    0.974852  NaN
# speed                                                   NaN  NaN
#
#                                            Pickup - time_y  \
# Distance (KM)                                          NaN
# Arrival at Destination - time_y                   0.980490
# Destination Long                                       NaN
# Pickup Long                                            NaN
# Confirmation - Weekday (Mo = 1)                        NaN
# Arrival at Pickup - Weekday (Mo = 1)                   NaN
# Pickup - Weekday (Mo = 1)                              NaN
# Arrival at Destination - Weekday (Mo = 1)              NaN
# Placement - Weekday (Mo = 1)                           NaN
# Temperature                                            NaN
# No_of_Ratings                                          NaN
# Precipitation in millimeters                           NaN
# Placement_time_x                                       NaN
# Age                                                    NaN
# Pickup - time_y                                   1.000000
# Arrival at Pickup - time_y                        0.989847
# Confirmation - time_x                                  NaN
# Confirmation - Day of Month                            NaN
# Arrival at Pickup - Day of Month                       NaN
# Pickup - Day of Month                                  NaN
# Arrival at Destination - Day of Month                  NaN
# Placement - Day of Month                               NaN
# Pickup - time_x                                        NaN
# Confirmation - time_y                             0.972223
# Placement_time_y                                  0.945447
# Arrival at Pickup - time_x                             NaN
# No_Of_Orders                                           NaN
# Average_Rating                                         NaN
# Pickup Lat                                             NaN
# Destination Lat                                        NaN
# Arrival at Destination - time_x                        NaN
# speed                                                  NaN
#
#                                            Arrival at Pickup - time_y  \
# Distance (KM)                                                     NaN
# Arrival at Destination - time_y                              0.960854
# Destination Long                                                  NaN
# Pickup Long                                                       NaN
# Confirmation - Weekday (Mo = 1)                                   NaN
# Arrival at Pickup - Weekday (Mo = 1)                              NaN
# Pickup - Weekday (Mo = 1)                                         NaN
# Arrival at Destination - Weekday (Mo = 1)                         NaN
# Placement - Weekday (Mo = 1)                                      NaN
# Temperature                                                       NaN
# No_of_Ratings                                                     NaN
# Precipitation in millimeters                                      NaN
# Placement_time_x                                                  NaN
# Age                                                               NaN
# Pickup - time_y                                              0.989847
# Arrival at Pickup - time_y                                   1.000000
# Confirmation - time_x                                             NaN
# Confirmation - Day of Month                                       NaN
# Arrival at Pickup - Day of Month                                  NaN
# Pickup - Day of Month                                             NaN
# Arrival at Destination - Day of Month                             NaN
# Placement - Day of Month                                          NaN
# Pickup - time_x                                                   NaN
# Confirmation - time_y                                        0.989266
# Placement_time_y                                             0.966701
# Arrival at Pickup - time_x                                        NaN
# No_Of_Orders                                                      NaN
# Average_Rating                                                    NaN
# Pickup Lat                                                        NaN
# Destination Lat                                                   NaN
# Arrival at Destination - time_x                                   NaN
# speed                                                             NaN
#
#                                            Confirmation - time_x  \
# Distance (KM)                                                NaN
# Arrival at Destination - time_y                              NaN
# Destination Long                                             NaN
# Pickup Long                                                  NaN
# Confirmation - Weekday (Mo = 1)                              NaN
# Arrival at Pickup - Weekday (Mo = 1)                         NaN
# Pickup - Weekday (Mo = 1)                                    NaN
# Arrival at Destination - Weekday (Mo = 1)                    NaN
# Placement - Weekday (Mo = 1)                                 NaN
# Temperature                                                  NaN
# No_of_Ratings                                                NaN
# Precipitation in millimeters                                 NaN
# Placement_time_x                                        0.993892
# Age                                                          NaN
# Pickup - time_y                                              NaN
# Arrival at Pickup - time_y                                   NaN
# Confirmation - time_x                                   1.000000
# Confirmation - Day of Month                                  NaN
# Arrival at Pickup - Day of Month                             NaN
# Pickup - Day of Month                                        NaN
# Arrival at Destination - Day of Month                        NaN
# Placement - Day of Month                                     NaN
# Pickup - time_x                                         0.993299
# Confirmation - time_y                                        NaN
# Placement_time_y                                             NaN
# Arrival at Pickup - time_x                              0.996934
# No_Of_Orders                                                 NaN
# Average_Rating                                               NaN
# Pickup Lat                                                   NaN
# Destination Lat                                              NaN
# Arrival at Destination - time_x                         0.983088
# speed                                                        NaN
#
#                                            Confirmation - Day of Month  \
# Distance (KM)                                                      NaN
# Arrival at Destination - time_y                                    NaN
# Destination Long                                                   NaN
# Pickup Long                                                        NaN
# Confirmation - Weekday (Mo = 1)                                    NaN
# Arrival at Pickup - Weekday (Mo = 1)                               NaN
# Pickup - Weekday (Mo = 1)                                          NaN
# Arrival at Destination - Weekday (Mo = 1)                          NaN
# Placement - Weekday (Mo = 1)                                       NaN
# Temperature                                                        NaN
# No_of_Ratings                                                      NaN
# Precipitation in millimeters                                       NaN
# Placement_time_x                                                   NaN
# Age                                                                NaN
# Pickup - time_y                                                    NaN
# Arrival at Pickup - time_y                                         NaN
# Confirmation - time_x                                              NaN
# Confirmation - Day of Month                                   1.000000
# Arrival at Pickup - Day of Month                              1.000000
# Pickup - Day of Month                                         1.000000
# Arrival at Destination - Day of Month                         1.000000
# Placement - Day of Month                                      0.999998
# Pickup - time_x                                                    NaN
# Confirmation - time_y                                              NaN
# Placement_time_y                                                   NaN
# Arrival at Pickup - time_x                                         NaN
# No_Of_Orders                                                       NaN
# Average_Rating                                                     NaN
# Pickup Lat                                                         NaN
# Destination Lat                                                    NaN
# Arrival at Destination - time_x                                    NaN
# speed                                                              NaN
#
#                                            Arrival at Pickup - Day of Month  \
# Distance (KM)                                                           NaN
# Arrival at Destination - time_y                                         NaN
# Destination Long                                                        NaN
# Pickup Long                                                             NaN
# Confirmation - Weekday (Mo = 1)                                         NaN
# Arrival at Pickup - Weekday (Mo = 1)                                    NaN
# Pickup - Weekday (Mo = 1)                                               NaN
# Arrival at Destination - Weekday (Mo = 1)                               NaN
# Placement - Weekday (Mo = 1)                                            NaN
# Temperature                                                             NaN
# No_of_Ratings                                                           NaN
# Precipitation in millimeters                                            NaN
# Placement_time_x                                                        NaN
# Age                                                                     NaN
# Pickup - time_y                                                         NaN
# Arrival at Pickup - time_y                                              NaN
# Confirmation - time_x                                                   NaN
# Confirmation - Day of Month                                        1.000000
# Arrival at Pickup - Day of Month                                   1.000000
# Pickup - Day of Month                                              1.000000
# Arrival at Destination - Day of Month                              1.000000
# Placement - Day of Month                                           0.999998
# Pickup - time_x                                                         NaN
# Confirmation - time_y                                                   NaN
# Placement_time_y                                                        NaN
# Arrival at Pickup - time_x                                              NaN
# No_Of_Orders                                                            NaN
# Average_Rating                                                          NaN
# Pickup Lat                                                              NaN
# Destination Lat                                                         NaN
# Arrival at Destination - time_x                                         NaN
# speed                                                                   NaN
#
#                                            Pickup - Day of Month  \
# Distance (KM)                                                NaN
# Arrival at Destination - time_y                              NaN
# Destination Long                                             NaN
# Pickup Long                                                  NaN
# Confirmation - Weekday (Mo = 1)                              NaN
# Arrival at Pickup - Weekday (Mo = 1)                         NaN
# Pickup - Weekday (Mo = 1)                                    NaN
# Arrival at Destination - Weekday (Mo = 1)                    NaN
# Placement - Weekday (Mo = 1)                                 NaN
# Temperature                                                  NaN
# No_of_Ratings                                                NaN
# Precipitation in millimeters                                 NaN
# Placement_time_x                                             NaN
# Age                                                          NaN
# Pickup - time_y                                              NaN
# Arrival at Pickup - time_y                                   NaN
# Confirmation - time_x                                        NaN
# Confirmation - Day of Month                             1.000000
# Arrival at Pickup - Day of Month                        1.000000
# Pickup - Day of Month                                   1.000000
# Arrival at Destination - Day of Month                   1.000000
# Placement - Day of Month                                0.999998
# Pickup - time_x                                              NaN
# Confirmation - time_y                                        NaN
# Placement_time_y                                             NaN
# Arrival at Pickup - time_x                                   NaN
# No_Of_Orders                                                 NaN
# Average_Rating                                               NaN
# Pickup Lat                                                   NaN
# Destination Lat                                              NaN
# Arrival at Destination - time_x                              NaN
# speed                                                        NaN
#
#                                            Arrival at Destination - Day of Month  \
# Distance (KM)                                                                NaN
# Arrival at Destination - time_y                                              NaN
# Destination Long                                                             NaN
# Pickup Long                                                                  NaN
# Confirmation - Weekday (Mo = 1)                                              NaN
# Arrival at Pickup - Weekday (Mo = 1)                                         NaN
# Pickup - Weekday (Mo = 1)                                                    NaN
# Arrival at Destination - Weekday (Mo = 1)                                    NaN
# Placement - Weekday (Mo = 1)                                                 NaN
# Temperature                                                                  NaN
# No_of_Ratings                                                                NaN
# Precipitation in millimeters                                                 NaN
# Placement_time_x                                                             NaN
# Age                                                                          NaN
# Pickup - time_y                                                              NaN
# Arrival at Pickup - time_y                                                   NaN
# Confirmation - time_x                                                        NaN
# Confirmation - Day of Month                                             1.000000
# Arrival at Pickup - Day of Month                                        1.000000
# Pickup - Day of Month                                                   1.000000
# Arrival at Destination - Day of Month                                   1.000000
# Placement - Day of Month                                                0.999998
# Pickup - time_x                                                              NaN
# Confirmation - time_y                                                        NaN
# Placement_time_y                                                             NaN
# Arrival at Pickup - time_x                                                   NaN
# No_Of_Orders                                                                 NaN
# Average_Rating                                                               NaN
# Pickup Lat                                                                   NaN
# Destination Lat                                                              NaN
# Arrival at Destination - time_x                                              NaN
# speed                                                                        NaN
#
#                                            Placement - Day of Month  \
# Distance (KM)                                                   NaN
# Arrival at Destination - time_y                                 NaN
# Destination Long                                                NaN
# Pickup Long                                                     NaN
# Confirmation - Weekday (Mo = 1)                                 NaN
# Arrival at Pickup - Weekday (Mo = 1)                            NaN
# Pickup - Weekday (Mo = 1)                                       NaN
# Arrival at Destination - Weekday (Mo = 1)                       NaN
# Placement - Weekday (Mo = 1)                                    NaN
# Temperature                                                     NaN
# No_of_Ratings                                                   NaN
# Precipitation in millimeters                                    NaN
# Placement_time_x                                                NaN
# Age                                                             NaN
# Pickup - time_y                                                 NaN
# Arrival at Pickup - time_y                                      NaN
# Confirmation - time_x                                           NaN
# Confirmation - Day of Month                                0.999998
# Arrival at Pickup - Day of Month                           0.999998
# Pickup - Day of Month                                      0.999998
# Arrival at Destination - Day of Month                      0.999998
# Placement - Day of Month                                   1.000000
# Pickup - time_x                                                 NaN
# Confirmation - time_y                                           NaN
# Placement_time_y                                                NaN
# Arrival at Pickup - time_x                                      NaN
# No_Of_Orders                                                    NaN
# Average_Rating                                                  NaN
# Pickup Lat                                                      NaN
# Destination Lat                                                 NaN
# Arrival at Destination - time_x                                 NaN
# speed                                                           NaN
#
#                                            Pickup - time_x  \
# Distance (KM)                                          NaN
# Arrival at Destination - time_y                        NaN
# Destination Long                                       NaN
# Pickup Long                                            NaN
# Confirmation - Weekday (Mo = 1)                        NaN
# Arrival at Pickup - Weekday (Mo = 1)                   NaN
# Pickup - Weekday (Mo = 1)                              NaN
# Arrival at Destination - Weekday (Mo = 1)              NaN
# Placement - Weekday (Mo = 1)                           NaN
# Temperature                                            NaN
# No_of_Ratings                                          NaN
# Precipitation in millimeters                           NaN
# Placement_time_x                                  0.986032
# Age                                                    NaN
# Pickup - time_y                                        NaN
# Arrival at Pickup - time_y                             NaN
# Confirmation - time_x                             0.993299
# Confirmation - Day of Month                            NaN
# Arrival at Pickup - Day of Month                       NaN
# Pickup - Day of Month                                  NaN
# Arrival at Destination - Day of Month                  NaN
# Placement - Day of Month                               NaN
# Pickup - time_x                                   1.000000
# Confirmation - time_y                                  NaN
# Placement_time_y                                       NaN
# ...
# speed                                                  NaN
#
#                                            Confirmation - time_y  \
# Distance (KM)                                                NaN
# Arrival at Destination - time_y                         0.928085
# Destination Long                                             NaN
# Pickup Long                                                  NaN
# Confirmation - Weekday (Mo = 1)                              NaN
# Arrival at Pickup - Weekday (Mo = 1)                         NaN
# Pickup - Weekday (Mo = 1)                                    NaN
# Arrival at Destination - Weekday (Mo = 1)                    NaN
# Placement - Weekday (Mo = 1)                                 NaN
# Temperature                                                  NaN
# No_of_Ratings                                                NaN
# Precipitation in millimeters                                 NaN
# Placement_time_x                                             NaN
# Age                                                          NaN
# Pickup - time_y                                         0.972223
# Arrival at Pickup - time_y                              0.989266
# Confirmation - time_x                                        NaN
# Confirmation - Day of Month                                  NaN
# Arrival at Pickup - Day of Month                             NaN
# Pickup - Day of Month                                        NaN
# Arrival at Destination - Day of Month                        NaN
# Placement - Day of Month                                     NaN
# Pickup - time_x                                              NaN
# Confirmation - time_y                                   1.000000
# Placement_time_y                                        0.983584
# Arrival at Pickup - time_x                                   NaN
# No_Of_Orders                                                 NaN
# Average_Rating                                               NaN
# Pickup Lat                                                   NaN
# Destination Lat                                              NaN
# Arrival at Destination - time_x                              NaN
# speed                                                        NaN
#
#                                            Placement_time_y  \
# Distance (KM)                                           NaN
# Arrival at Destination - time_y                         NaN
# Destination Long                                        NaN
# Pickup Long                                             NaN
# Confirmation - Weekday (Mo = 1)                         NaN
# Arrival at Pickup - Weekday (Mo = 1)                    NaN
# Pickup - Weekday (Mo = 1)                               NaN
# Arrival at Destination - Weekday (Mo = 1)               NaN
# Placement - Weekday (Mo = 1)                            NaN
# Temperature                                             NaN
# No_of_Ratings                                           NaN
# Precipitation in millimeters                            NaN
# Placement_time_x                                        NaN
# Age                                                     NaN
# Pickup - time_y                                    0.945447
# Arrival at Pickup - time_y                         0.966701
# Confirmation - time_x                                   NaN
# Confirmation - Day of Month                             NaN
# Arrival at Pickup - Day of Month                        NaN
# Pickup - Day of Month                                   NaN
# Arrival at Destination - Day of Month                   NaN
# Placement - Day of Month                                NaN
# Pickup - time_x                                         NaN
# Confirmation - time_y                              0.983584
# Placement_time_y                                   1.000000
# Arrival at Pickup - time_x                              NaN
# No_Of_Orders                                            NaN
# Average_Rating                                          NaN
# Pickup Lat                                              NaN
# Destination Lat                                         NaN
# Arrival at Destination - time_x                         NaN
# speed                                                   NaN
#
#                                            Arrival at Pickup - time_x  \
# Distance (KM)                                                     NaN
# Arrival at Destination - time_y                                   NaN
# Destination Long                                                  NaN
# Pickup Long                                                       NaN
# Confirmation - Weekday (Mo = 1)                                   NaN
# Arrival at Pickup - Weekday (Mo = 1)                              NaN
# Pickup - Weekday (Mo = 1)                                         NaN
# Arrival at Destination - Weekday (Mo = 1)                         NaN
# Placement - Weekday (Mo = 1)                                      NaN
# Temperature                                                       NaN
# No_of_Ratings                                                     NaN
# Precipitation in millimeters                                      NaN
# Placement_time_x                                             0.990022
# Age                                                               NaN
# Pickup - time_y                                                   NaN
# Arrival at Pickup - time_y                                        NaN
# Confirmation - time_x                                        0.996934
# Confirmation - Day of Month                                       NaN
# Arrival at Pickup - Day of Month                                  NaN
# Pickup - Day of Month                                             NaN
# Arrival at Destination - Day of Month                             NaN
# Placement - Day of Month                                          NaN
# Pickup - time_x                                              0.996281
# Confirmation - time_y                                             NaN
# Placement_time_y                                                  NaN
# Arrival at Pickup - time_x                                   1.000000
# No_Of_Orders                                                      NaN
# Average_Rating                                                    NaN
# Pickup Lat                                                        NaN
# Destination Lat                                                   NaN
# Arrival at Destination - time_x                              0.988645
# speed                                                             NaN
#
#                                            No_Of_Orders  Average_Rating  \
# Distance (KM)                                       NaN             NaN
# Arrival at Destination - time_y                     NaN             NaN
# Destination Long                                    NaN             NaN
# Pickup Long                                         NaN             NaN
# Confirmation - Weekday (Mo = 1)                     NaN             NaN
# Arrival at Pickup - Weekday (Mo = 1)                NaN             NaN
# Pickup - Weekday (Mo = 1)                           NaN             NaN
# Arrival at Destination - Weekday (Mo = 1)           NaN             NaN
# Placement - Weekday (Mo = 1)                        NaN             NaN
# Temperature                                         NaN             NaN
# No_of_Ratings                                       NaN             NaN
# Precipitation in millimeters                        NaN             NaN
# Placement_time_x                                    NaN             NaN
# Age                                                 NaN             NaN
# Pickup - time_y                                     NaN             NaN
# Arrival at Pickup - time_y                          NaN             NaN
# Confirmation - time_x                               NaN             NaN
# Confirmation - Day of Month                         NaN             NaN
# Arrival at Pickup - Day of Month                    NaN             NaN
# Pickup - Day of Month                               NaN             NaN
# Arrival at Destination - Day of Month               NaN             NaN
# Placement - Day of Month                            NaN             NaN
# Pickup - time_x                                     NaN             NaN
# Confirmation - time_y                               NaN             NaN
# Placement_time_y                                    NaN             NaN
# Arrival at Pickup - time_x                          NaN             NaN
# No_Of_Orders                                        1.0             NaN
# Average_Rating                                      NaN             1.0
# Pickup Lat                                          NaN             NaN
# Destination Lat                                     NaN             NaN
# Arrival at Destination - time_x                     NaN             NaN
# speed                                               NaN             NaN
#
#                                            Pickup Lat  Destination Lat  \
# Distance (KM)                                     NaN              NaN
# Arrival at Destination - time_y                   NaN              NaN
# Destination Long                                  NaN              NaN
# Pickup Long                                       NaN              NaN
# Confirmation - Weekday (Mo = 1)                   NaN              NaN
# Arrival at Pickup - Weekday (Mo = 1)              NaN              NaN
# Pickup - Weekday (Mo = 1)                         NaN              NaN
# Arrival at Destination - Weekday (Mo = 1)         NaN              NaN
# Placement - Weekday (Mo = 1)                      NaN              NaN
# Temperature                                       NaN              NaN
# No_of_Ratings                                     NaN              NaN
# Precipitation in millimeters                      NaN              NaN
# Placement_time_x                                  NaN              NaN
# Age                                               NaN              NaN
# Pickup - time_y                                   NaN              NaN
# Arrival at Pickup - time_y                        NaN              NaN
# Confirmation - time_x                             NaN              NaN
# Confirmation - Day of Month                       NaN              NaN
# Arrival at Pickup - Day of Month                  NaN              NaN
# Pickup - Day of Month                             NaN              NaN
# Arrival at Destination - Day of Month             NaN              NaN
# Placement - Day of Month                          NaN              NaN
# Pickup - time_x                                   NaN              NaN
# Confirmation - time_y                             NaN              NaN
# Placement_time_y                                  NaN              NaN
# Arrival at Pickup - time_x                        NaN              NaN
# No_Of_Orders                                      NaN              NaN
# Average_Rating                                    NaN              NaN
# Pickup Lat                                        1.0              NaN
# Destination Lat                                   NaN              1.0
# Arrival at Destination - time_x                   NaN              NaN
# speed                                             NaN              NaN
#
#                                            Arrival at Destination - time_x  \
# Distance (KM)                                                          NaN
# Arrival at Destination - time_y                                        NaN
# Destination Long                                                       NaN
# Pickup Long                                                            NaN
# Confirmation - Weekday (Mo = 1)                                        NaN
# Arrival at Pickup - Weekday (Mo = 1)                                   NaN
# Pickup - Weekday (Mo = 1)                                              NaN
# Arrival at Destination - Weekday (Mo = 1)                              NaN
# Placement - Weekday (Mo = 1)                                           NaN
# Temperature                                                            NaN
# No_of_Ratings                                                          NaN
# Precipitation in millimeters                                           NaN
# Placement_time_x                                                  0.974852
# Age                                                                    NaN
# Pickup - time_y                                                        NaN
# Arrival at Pickup - time_y                                             NaN
# Confirmation - time_x                                             0.983088
# Confirmation - Day of Month                                            NaN
# Arrival at Pickup - Day of Month                                       NaN
# Pickup - Day of Month                                                  NaN
# Arrival at Destination - Day of Month                                  NaN
# Placement - Day of Month                                               NaN
# Pickup - time_x                                                   0.992800
# Confirmation - time_y                                                  NaN
# Placement_time_y                                                       NaN
# Arrival at Pickup - time_x                                        0.988645
# No_Of_Orders                                                           NaN
# Average_Rating                                                         NaN
# Pickup Lat                                                             NaN
# Destination Lat                                                        NaN
# Arrival at Destination - time_x                                   1.000000
# speed                                                                  NaN
#
#                                            speed
# Distance (KM)                                NaN
# Arrival at Destination - time_y              NaN
# Destination Long                             NaN
# Pickup Long                                  NaN
# Confirmation - Weekday (Mo = 1)              NaN
# Arrival at Pickup - Weekday (Mo = 1)         NaN
# Pickup - Weekday (Mo = 1)                    NaN
# Arrival at Destination - Weekday (Mo = 1)    NaN
# Placement - Weekday (Mo = 1)                 NaN
# Temperature                                  NaN
# No_of_Ratings                                NaN
# Precipitation in millimeters                 NaN
# Placement_time_x                             NaN
# Age                                          NaN
# Pickup - time_y                              NaN
# Arrival at Pickup - time_y                   NaN
# Confirmation - time_x                        NaN
# Confirmation - Day of Month                  NaN
# Arrival at Pickup - Day of Month             NaN
# Pickup - Day of Month                        NaN
# Arrival at Destination - Day of Month        NaN
# Placement - Day of Month                     NaN
# Pickup - time_x                              NaN
# Confirmation - time_y                        NaN
# Placement_time_y                             NaN
# Arrival at Pickup - time_x                   NaN
# No_Of_Orders                                 NaN
# Average_Rating                               NaN
# Pickup Lat                                   NaN
# Destination Lat                              NaN
# Arrival at Destination - time_x              NaN
# speed                                        1.0

# %%
#Change column from object type to integer, 0 and 1
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train_data['Personal or Business'] = le.fit_transform(train_data['Personal or Business'])
test_data['Personal or Business'] = le.transform(test_data['Personal or Business'])

# %%
#Change Platform type from intergers to categories
train_data['Platform Type'] = train_data['Platform Type'].replace([1, 2, 3, 4], ['Type_1', 'Type_2', 'Type_3', 'Type_4'])
test_data['Platform Type'] = test_data['Platform Type'].replace([1, 2, 3, 4], ['Type_1', 'Type_2', 'Type_3', 'Type_4'])

# %%
#Create dummy variables
traindata = pd.get_dummies(train_data, drop_first=True)
testdata = pd.get_dummies(test_data, drop_first=True)

# %%
traindata.head()
# Out:
#    Personal or Business  Placement - Day of Month  \
# 0                     0                         9
# 1                     1                        18
# 2                     0                        31
# 3                     1                         2
# 4                     1                        22
#
#    Placement - Weekday (Mo = 1)  Confirmation - Day of Month  \
# 0                             5                            9
# 1                             5                           18
# 2                             5                           31
# 3                             2                            2
# 4                             2                           22
#
#    Confirmation - Weekday (Mo = 1)  Arrival at Pickup - Day of Month  \
# 0                                5                                 9
# 1                                5                                18
# 2                                5                                31
# 3                                2                                 2
# 4                                2                                22
#
#    Arrival at Pickup - Weekday (Mo = 1)  Pickup - Day of Month  \
# 0                                     5                      9
# 1                                     5                     18
# 2                                     5                     31
# 3                                     2                      2
# 4                                     2                     22
#
#    Pickup - Weekday (Mo = 1)  Arrival at Destination - Day of Month  \
# 0                          5                                      9
# 1                          5                                     18
# 2                          5                                     31
# 3                          2                                      2
# 4                          2                                     22
#
#    Arrival at Destination - Weekday (Mo = 1)  Distance (KM)  Temperature  \
# 0                                          5              4         20.4
# 1                                          5             20         24.5
# 2                                          5              6         24.7
# 3                                          2             18         15.2
# 4                                          2              7         19.2
#
#    Precipitation in millimeters  Pickup Lat  Pickup Long  Destination Lat  \
# 0                           0.0   -1.317755    36.830370        -1.300406
# 1                           0.0   -1.326774    36.787807        -1.356237
# 2                           0.0   -1.255189    36.782203        -1.273412
# 3                           0.0   -1.290315    36.757377        -1.223520
# 4                           0.0   -1.273524    36.799220        -1.300431
#
#    Destination Long  Time from Pickup to Arrival  No_Of_Orders   Age  \
# 0         36.829741                          745          1637  1309
# 1         36.904295                         2886          1637  1309
# 2         36.818206                         2615          1637  1309
# 3         36.802061                         2986          1637  1309
# 4         36.752427                         1602          1637  1309
#
#    Average_Rating  No_of_Ratings  Placement_time_x  Placement_time_y  \
# 0            13.8            549          0.588609         -0.808418
# 1            13.8            549         -0.822351         -0.568981
# 2            13.8            549         -0.223605         -0.974680
# 3            13.8            549          0.950832         -0.309709
# 4            13.8            549          0.338054         -0.941127
#
#    Confirmation - time_x  Confirmation - time_y  \
# 0               0.572981              -0.819569
# 1              -0.822889              -0.568203
# 2              -0.312404              -0.949949
# 3               0.950403              -0.311022
# 4               0.332161              -0.943223
#
#    Arrival at Destination - time_x  Arrival at Destination - time_y  \
# 0                         0.342362                        -0.939568
# 1                        -0.967837                        -0.251577
# 2                        -0.561783                        -0.827285
# 3                         0.797233                        -0.603672
# 4                         0.146227                        -0.989251
#
#    Pickup - time_x  Pickup - time_y  Arrival at Pickup - time_x  \
# 0         0.392738        -0.919650                    0.481817
# 1        -0.894187        -0.447694                   -0.881441
# 2        -0.395278        -0.918561                   -0.342157
# 3         0.908569        -0.417735                    0.914607
# 4         0.260224        -0.965548                    0.275637
#
#    Arrival at Pickup - time_y     speed  Platform Type_Type_2  \
# 0                   -0.876272  0.005369                     0
# 1                   -0.472294  0.006930                     0
# 2                   -0.939643  0.002294                     0
# 3                   -0.404344  0.006028                     0
# 4                   -0.961262  0.004370                     1
#
#    Platform Type_Type_3  Platform Type_Type_4
# 0                     1                     0
# 1                     1                     0
# 2                     1                     0
# 3                     1                     0
# 4                     0                     0

# %%
#get correlated values
plt.figure(figsize = (15,15))
sns.heatmap(traindata.corr())

# %%
#No of ratings and No of orders are highly correlated, so we drop one
traindata.drop('No_of_Ratings', axis=1, inplace=True)
testdata.drop('No_of_Ratings', axis=1, inplace=True)

# %%
#Arrival at pickup and pickup are highly correlated, drop one
traindata.drop(['Arrival at Pickup - time_x', 'Arrival at Pickup - time_y', 'Arrival at Pickup - Day of Month', 'Arrival at Pickup - Weekday (Mo = 1)'], axis=1, inplace=True)
testdata.drop(['Arrival at Pickup - time_x', 'Arrival at Pickup - time_y', 'Arrival at Pickup - Day of Month', 'Arrival at Pickup - Weekday (Mo = 1)'], axis=1, inplace=True)

# %%
#Orders are all delivered on the same day they were ordered, which creates a repitition, e.g Placement - day of month, Confirmation - day of month, Arrival at pickup - day of month, pickup - day of month, arrival at destination - day of month, all have the same data. This also applies to Weekday columns
traindata.drop(['Placement - Day of Month', 'Pickup - Day of Month', 'Arrival at Destination - Day of Month', 'Placement - Weekday (Mo = 1)', 'Pickup - Weekday (Mo = 1)', 'Arrival at Destination - Weekday (Mo = 1)'], axis=1, inplace=True)
testdata.drop(['Placement - Day of Month', 'Pickup - Day of Month', 'Placement - Weekday (Mo = 1)', 'Pickup - Weekday (Mo = 1)'], axis=1, inplace=True)

# %%
column_titles = [col for col in traindata.columns if col!= 'Time from Pickup to Arrival'] + ['Time from Pickup to Arrival']
traindata=traindata.reindex(columns=column_titles)

# %%
traindata.shape
# Out:
# (21201, 26)

# %%
testdata.shape
# Out:
# (7068, 22)

# %%
traindata.head()
# Out:
#    Personal or Business  Confirmation - Day of Month  \
# 0                     0                            9
# 1                     1                           18
# 2                     0                           31
# 3                     1                            2
# 4                     1                           22
#
#    Confirmation - Weekday (Mo = 1)  Distance (KM)  Temperature  \
# 0                                5              4         20.4
# 1                                5             20         24.5
# 2                                5              6         24.7
# 3                                2             18         15.2
# 4                                2              7         19.2
#
#    Precipitation in millimeters  Pickup Lat  Pickup Long  Destination Lat  \
# 0                           0.0   -1.317755    36.830370        -1.300406
# 1                           0.0   -1.326774    36.787807        -1.356237
# 2                           0.0   -1.255189    36.782203        -1.273412
# 3                           0.0   -1.290315    36.757377        -1.223520
# 4                           0.0   -1.273524    36.799220        -1.300431
#
#    Destination Long  No_Of_Orders   Age  Average_Rating  Placement_time_x  \
# 0         36.829741          1637  1309            13.8          0.588609
# 1         36.904295          1637  1309            13.8         -0.822351
# 2         36.818206          1637  1309            13.8         -0.223605
# 3         36.802061          1637  1309            13.8          0.950832
# 4         36.752427          1637  1309            13.8          0.338054
#
#    Placement_time_y  Confirmation - time_x  Confirmation - time_y  \
# 0         -0.808418               0.572981              -0.819569
# 1         -0.568981              -0.822889              -0.568203
# 2         -0.974680              -0.312404              -0.949949
# 3         -0.309709               0.950403              -0.311022
# 4         -0.941127               0.332161              -0.943223
#
#    Arrival at Destination - time_x  Arrival at Destination - time_y  \
# 0                         0.342362                        -0.939568
# 1                        -0.967837                        -0.251577
# 2                        -0.561783                        -0.827285
# 3                         0.797233                        -0.603672
# 4                         0.146227                        -0.989251
#
#    Pickup - time_x  Pickup - time_y     speed  Platform Type_Type_2  \
# 0         0.392738        -0.919650  0.005369                     0
# 1        -0.894187        -0.447694  0.006930                     0
# 2        -0.395278        -0.918561  0.002294                     0
# 3         0.908569        -0.417735  0.006028                     0
# 4         0.260224        -0.965548  0.004370                     1
#
#    Platform Type_Type_3  Platform Type_Type_4  Time from Pickup to Arrival
# 0                     1                     0                          745
# 1                     1                     0                         2886
# 2                     1                     0                         2615
# 3                     1                     0                         2986
# 4                     0                     0                         1602

# %%
testdata.head()
# Out:
#    Personal or Business  Confirmation - Day of Month  \
# 0                     0                           27
# 1                     1                           26
# 2                     0                           29
# 3                     0                            2
# 4                     0                           14
#
#    Confirmation - Weekday (Mo = 1)  Distance (KM)  Temperature  \
# 0                                3              8    23.258889
# 1                                2             19    23.258889
# 2                                5              9    19.700000
# 3                                1             15    16.400000
# 4                                4             15    21.300000
#
#    Precipitation in millimeters  Pickup Lat  Pickup Long  Destination Lat  \
# 0                           0.0   -1.333275    36.870815        -1.305249
# 1                           0.0   -1.312745    36.875715        -1.288435
# 2                           0.0   -1.255189    36.782203        -1.293393
# 3                           0.0   -1.310451    36.868724        -1.259542
# 4                           0.0   -1.333275    36.870815        -1.255189
#
#    Destination Long  No_Of_Orders   Age  Average_Rating  Placement_time_x  \
# 0         36.822390           439  1511            13.3          0.588609
# 1         36.760677           439  1511            13.3         -0.822351
# 2         36.790237           439  1511            13.3         -0.223605
# 3         36.787118           439  1511            13.3          0.950832
# 4         36.782203           439  1511            13.3          0.338054
#
#    Placement_time_y  Confirmation - time_x  Confirmation - time_y  \
# 0         -0.808418              -0.946203              -0.323573
# 1         -0.568981              -0.666749              -0.745282
# 2         -0.974680               0.007854              -0.999969
# 3         -0.309709               0.630224              -0.776413
# 4         -0.941127              -0.353203              -0.935547
#
#    Pickup - time_x  Pickup - time_y  Platform Type_Type_2  \
# 0        -0.973162        -0.230121                     0
# 1        -0.759839        -0.650111                     0
# 2        -0.125766        -0.992060                     0
# 3         0.479011        -0.877809                     0
# 4        -0.468765        -0.883323                     0
#
#    Platform Type_Type_3  Platform Type_Type_4
# 0                     1                     0
# 1                     0                     0
# 2                     1                     0
# 3                     1                     0
# 4                     1                     0

# %%
#  Dropping columns that are in traindata but not in testdata
cols_dropped = [col for col in traindata.columns if col not in testdata.columns and col != 'Time from Pickup to Arrival']
traindata.drop(cols_dropped, axis=1, inplace=True)

# %%
# Splitting traindata into train and cross validation sets
X = traindata.iloc[:, :-1].values
y = traindata.iloc[:, -1].values
X_train, X_cross, y_train, y_cross = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Models

# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# ### Polynimial Regression

# %% [markdown]
# ### Support Vector Regression

# %%
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
vector_predict = regressor.predict(X_cross)
vector_mse = mean_squared_error(y_cross,vector_predict)
vector_r2 = r2_score(y_cross,vector_predict)
print('MSE for Support Vector :',vector_mse)
print('R Squared for Support Vector :',vector_r2)
# Out:
# C:\Users\maruf\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# MSE for Support Vector : 1001832.7239761295
# R Squared for Support Vector : -0.032337307284454386

# %% [markdown]
# ### Decision Tree Regression

# %%
tree_reg = DecisionTreeRegressor(random_state = 0)
tree_reg.fit(X_train, y_train)
tree_pred = tree_reg.predict(X_cross)
tree_mse = mean_squared_error(y_cross,tree_pred)
tree_r2 = r2_score(y_cross,tree_pred)
print('MSE for Decision Tree :',tree_mse)
print('R Squared for Decision Tree :',tree_r2)
# Out:
# MSE for Decision Tree : 1280001.9707616128
# R Squared for Decision Tree : -0.318976468017951

# %% [markdown]
# ### Random Forest Regression

# %%
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(X_cross)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
forest_mse = mean_squared_error(y_cross,y_pred)
forest_r2 = r2_score(y_cross,y_pred)
forest_rmse = sqrt(forest_mse)
print('MSE for Random Forest :',forest_mse)
print('R Squared for Random Forest :',forest_r2)
print('RMSE for Random Forest :',forest_rmse)
# Out:
# MSE for Random Forest : 655224.2407309596
# R Squared for Random Forest : 0.32482498110151903
# RMSE for Random Forest : 809.4592273431439
